# %% [markdown]
# ### Ultima Correccion más reciente

# %%
from rdflib import Graph, Namespace, URIRef, Literal
from rdflib.namespace import RDF, RDFS, XSD, SKOS, DCTERMS
import pandas as pd
import re

# Helper function to clean and format strings for URIs
def clean_for_uri(text):
    if not text:
        return "unknown"
    a, b = 'áéíóúüñÁÉÍÓÚÜÑ', 'aeiouunAEIOUUN'
    trans = str.maketrans(a, b)
    text = text.translate(trans)
    text = re.sub(r'[<>:"/\\|?*(){}[\].,;\']', '', text)
    text = re.sub(r'\s+', '_', text)
    text = re.sub(r'[^a-zA-Z0-9_-]', '', text)
    return text.lower()[:100]

# Namespaces
g = Graph()
schema = Namespace("https://schema.org/")
dbp = Namespace("http://dbpedia.org/resource/")
myv = Namespace("http://example.org/myv/")
sko = SKOS
g.bind("schema", schema)
g.bind("dbp", dbp)
g.bind("myv", myv)
g.bind("skos", sko)
g.bind("dcterms", DCTERMS)

# Load CSVs
citations_df = pd.read_csv('citations.csv')
datos_con_referencias_df = pd.read_csv('scopus_detailed_papers.csv')
scopus_papers_df = pd.read_csv('scopus_papers.csv')

# Add Countries and Cities
locations = scopus_papers_df[['affiliation_country', 'affiliation_city']].dropna().drop_duplicates()
for _, row in locations.iterrows():
    countries = [country.strip() for country in row['affiliation_country'].split(';')]
    cities = [city.strip() for city in row['affiliation_city'].split(';')]
    for country, city in zip(countries, cities):
        country_uri = URIRef(dbp + clean_for_uri(country))
        city_uri = URIRef(dbp + clean_for_uri(city))
        g.add((country_uri, RDF.type, schema.Country))
        g.add((country_uri, schema.name, Literal(country)))
        g.add((city_uri, RDF.type, schema.City))
        g.add((city_uri, schema.name, Literal(city)))
        g.add((city_uri, schema.containsPlace, country_uri))

# Add Organizations and link to cities
organizations = scopus_papers_df[['affilname', 'affiliation_city', 'affiliation_country']].dropna().drop_duplicates()
for _, row in organizations.iterrows():
    org_uri = URIRef(schema + clean_for_uri(row['affilname']))
    cities = [city.strip() for city in row['affiliation_city'].split(';')]
    countries = [country.strip() for country in row['affiliation_country'].split(';')]
    g.add((org_uri, RDF.type, schema.Organization))
    g.add((org_uri, schema.name, Literal(row['affilname'])))
    for city, country in zip(cities, countries):
        city_uri = URIRef(dbp + clean_for_uri(city))
        country_uri = URIRef(dbp + clean_for_uri(country))
        g.add((org_uri, schema.location, city_uri))
        g.add((city_uri, schema.containsPlace, country_uri))

# Add Persons and their Affiliations (Schema:Person -> Schema:affiliation -> Schema:Organization -> Schema:location -> Schema:City -> Schema:containsPlace -> Schema:Country)
for _, row in datos_con_referencias_df[['author_names', 'affilname', 'affiliation_city', 'affiliation_country']].dropna().iterrows():
    authors = row['author_names'].split(';')
    affiliations = row['affilname'].split(';')
    cities = row['affiliation_city'].split(';')
    countries = row['affiliation_country'].split(';')
    
    # Ensure all lists have the same length by truncating or padding with "unknown"
    max_len = max(len(authors), len(affiliations), len(cities), len(countries))
    authors += ["unknown"] * (max_len - len(authors))
    affiliations += ["unknown"] * (max_len - len(affiliations))
    cities += ["unknown"] * (max_len - len(cities))
    countries += ["unknown"] * (max_len - len(countries))
    
    for author, affiliation, city, country in zip(authors, affiliations, cities, countries):
        # Create URIs for each entity
        author_uri = URIRef(schema + clean_for_uri(author.strip()))
        org_uri = URIRef(schema + clean_for_uri(affiliation.strip()))
        city_uri = URIRef(dbp + clean_for_uri(city.strip()))
        country_uri = URIRef(dbp + clean_for_uri(country.strip()))
        
        # Add Person and their affiliation
        g.add((author_uri, RDF.type, schema.Person))
        g.add((author_uri, schema.name, Literal(author.strip())))
        g.add((author_uri, schema.affiliation, org_uri))
        
        # Add Organization and its location
        g.add((org_uri, RDF.type, schema.Organization))
        g.add((org_uri, schema.name, Literal(affiliation.strip())))
        g.add((org_uri, schema.location, city_uri))
        
        # Add City and its country
        g.add((city_uri, RDF.type, schema.City))
        g.add((city_uri, schema.name, Literal(city.strip())))
        g.add((city_uri, schema.containsPlace, country_uri))
        
        # Add Country
        g.add((country_uri, RDF.type, schema.Country))
        g.add((country_uri, schema.name, Literal(country.strip())))

# Normalize and Add Keywords (SKOS Concepts)
keywords = scopus_papers_df['authkeywords'].dropna().str.split('|').explode().str.strip().str.lower().drop_duplicates()
for keyword in keywords:
    concept_uri = URIRef(myv + "concept/" + clean_for_uri(keyword))
    g.add((concept_uri, RDF.type, SKOS.Concept))
    g.add((concept_uri, RDFS.label, Literal(keyword)))

# Add Periodicals
journals = datos_con_referencias_df[datos_con_referencias_df['aggregationType'] == 'Journal']
for _, row in journals.iterrows():
    periodical_uri = URIRef(schema + clean_for_uri(row['publicationName'] if not pd.isna(row['publicationName']) else f"journal_{_}"))
    g.add((periodical_uri, RDF.type, schema.Periodical))
    g.add((periodical_uri, schema.identifier, Literal(row['publicationName'] if not pd.isna(row['publicationName']) else f"journal_{_}")))
    g.add((periodical_uri, schema.name, Literal(row['aggregationType'] if not pd.isna(row['aggregationType']) else "Journal")))

# Add Articles
for _, row in scopus_papers_df.iterrows():
    if pd.isna(row['doi']):
        continue
    article_uri = URIRef(schema + clean_for_uri(row['doi']))
    g.add((article_uri, RDF.type, schema.Article))
    g.add((article_uri, schema.identifier, Literal(row['doi'])))
    g.add((article_uri, schema.title, Literal(row['title'])))
    if not pd.isna(row['description']):
        g.add((article_uri, schema.description, Literal(row['description'])))
    if not pd.isna(row['coverDate']):
        g.add((article_uri, schema.datePublished, Literal(row['coverDate'], datatype=XSD.date)))
    if not pd.isna(row['citedby_count']):
        g.add((article_uri, myv.citationCount, Literal(row['citedby_count'], datatype=XSD.integer)))
    if not pd.isna(row['authkeywords']):
        for keyword in row['authkeywords'].split('|'):
            concept_uri = URIRef(myv + "concept/" + clean_for_uri(keyword.strip().lower()))
            g.add((article_uri, DCTERMS.subject, concept_uri))
    if not pd.isna(row['author_names']):
        for author_name in row['author_names'].split(';'):
            author_uri = URIRef(schema + clean_for_uri(author_name.strip()))
            g.add((author_uri, RDF.type, schema.Person))
            g.add((author_uri, schema.name, Literal(author_name.strip())))
            g.add((article_uri, schema.author, author_uri))
    if not pd.isna(row['publicationName']):
        periodical_uri = URIRef(schema + clean_for_uri(row['publicationName']))
        g.add((article_uri, schema.isPartOf, periodical_uri))
        g.add((periodical_uri, schema.hasPart, article_uri))

# Add References as myv:Observation
for _, row in citations_df.dropna(subset=['DOI', 'Paper DOI']).iterrows():
    source_uri = URIRef(schema + clean_for_uri(row['DOI']))
    target_uri = URIRef(schema + clean_for_uri(row['Paper DOI']))
    observation_uri = URIRef(myv + "observation/" + clean_for_uri(row['DOI'] + "_to_" + row['Paper DOI']))
    g.add((observation_uri, RDF.type, myv.Observation))
    g.add((observation_uri, schema.citation, source_uri))
    g.add((observation_uri, schema.citation, target_uri))

# Serialize RDF to Turtle format
g.serialize("articles_data_cleaned_10.ttl", format="turtle")
# Out:
# <Graph identifier=N170aa100e90c40b6a06cd75cb439e65a (<class 'rdflib.graph.Graph'>)>

# %% [markdown]
# # Extraccion de Keyword. Enlazado de datos e enrequecimiento de datos directo a GraphDB
#  ## Existen errores  al cargar los datos a graphDB

# %%
# Configuración del endpoint de DBpedia Spotlight
DBPEDIA_ENDPOINT = "https://api.dbpedia-spotlight.org/en/annotate"
HEADERS = {"Accept": "application/json"}

# Configuración de GraphDB
GRAPHDB_ENDPOINT = "http://DESKTOP-OPG5BNF:7200/repositories/articles_data_cleaned_10_conexion"
GRAPHDB_UPDATE = "http://DESKTOP-OPG5BNF:7200/repositories/articles_data_cleaned_10_conexion"

# Función para limpiar texto para URIs
def clean_for_uri(text):
    import re
    if not text:
        return "unknown"
    text = re.sub(r"[^\w\s-]", "", text)  # Remover caracteres especiales
    text = re.sub(r"\s+", "_", text.strip())  # Reemplazar espacios por guiones bajos
    return text.lower()[:100]

# Función para enlazar palabras clave con DBpedia
def link_keywords_to_dbpedia(keywords, confidence=0.5, support=20):
    linked_entities = {}
    for keyword in keywords:
        params = {
            "text": keyword,
            "confidence": confidence,
            "support": support
        }
        response = requests.get(DBPEDIA_ENDPOINT, headers=HEADERS, params=params)
        if response.status_code == 200:
            data = response.json()
            if "Resources" in data:
                linked_entities[keyword] = [
                    {"uri": res["@URI"], "surfaceForm": res["@surfaceForm"]} for res in data["Resources"]
                ]
    return linked_entities

# Paso 1: Consultar las palabras clave del grafo en GraphDB
def get_keywords_from_graphdb(endpoint, limit=10):
    sparql = SPARQLWrapper(endpoint)
    sparql.setQuery(f"""
        PREFIX myv: <http://example.org/myv/>
        PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
        
        SELECT DISTINCT ?keyword
        WHERE {{
            # ?concept a skos:Concept ;
                     rdfs:label ?keyword .
        }}
        LIMIT {limit}
    """)
    sparql.setReturnFormat(JSON)
    results = sparql.query().convert()
    return [result["keyword"]["value"] for result in results["results"]["bindings"]]

# Paso 2: Crear triples enriquecidos y cargarlos a GraphDB
def upload_enriched_triples_to_graphdb(linked_data, graphdb_update_url):
    sparql_update = """
        PREFIX schema: <http://schema.org/>
        INSERT DATA {
    """
    for keyword, entities in linked_data.items():
        keyword_uri = f"<http://example.org/myv/concept/{clean_for_uri(keyword)}>"
        for entity in entities:
            dbpedia_uri = f"<{entity['uri']}>"
            sparql_update += f"    {keyword_uri} schema:sameAs {dbpedia_uri} .\n"
    sparql_update += "}"

    # Enviar la consulta SPARQL
    response = requests.post(
        graphdb_update_url,
        data=sparql_update,
        headers={"Content-Type": "application/sparql-update"}
    )
    if response.status_code == 204:
        print("Datos enriquecidos cargados exitosamente a GraphDB.")
    else:
        print(f"Error al cargar los datos a GraphDB: {response.status_code}, {response.text}")

# Ejecutar el proceso completo
keywords = get_keywords_from_graphdb(GRAPHDB_ENDPOINT, limit=10)  # Consultar 10 palabras clave
linked_data = link_keywords_to_dbpedia(keywords, confidence=0.5)  # Enlazar con DBpedia Spotlight
upload_enriched_triples_to_graphdb(linked_data, GRAPHDB_UPDATE)  # Cargar datos enriquecidos en GraphDB
# Out:
# Error al cargar los datos a GraphDB: 415, Unsupported MIME type: application/sparql-update

# %% [markdown]
# # Extracion de keywords y enlazado de datos a la DBpedia  desde GraphDB

# %%
import requests
from SPARQLWrapper import SPARQLWrapper, JSON

# Configuración del endpoint de DBpedia Spotlight
DBPEDIA_ENDPOINT = "https://api.dbpedia-spotlight.org/en/annotate"
HEADERS = {"Accept": "application/json"}

# Configuración de GraphDB
GRAPHDB_ENDPOINT = "http://DESKTOP-OPG5BNF:7200/repositories/articles_data_cleaned_10_conexion"

# Función para consultar palabras clave desde GraphDB
def get_keywords_from_graphdb(endpoint, limit=10):
    sparql = SPARQLWrapper(endpoint)
    sparql.setQuery(f"""
        PREFIX myv: <http://example.org/myv/>
        PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
        
        SELECT DISTINCT ?keyword
        WHERE {{
            # ?concept a skos:Concept ;
                     rdfs:label ?keyword .
        }}
        LIMIT {limit}
    """)
    sparql.setReturnFormat(JSON)
    results = sparql.query().convert()
    return [result["keyword"]["value"] for result in results["results"]["bindings"]]

# Función para consultar entidades relacionadas en DBpedia Spotlight
def link_keywords_to_dbpedia(keywords, confidence=0.7, support=20):
    linked_entities = {}
    for keyword in keywords:
        print(f"Consultando DBpedia Spotlight para: {keyword}")
        params = {
            "text": keyword,
            "confidence": confidence,
            "support": support
        }
        response = requests.get(DBPEDIA_ENDPOINT, headers=HEADERS, params=params)
        if response.status_code == 200:
            data = response.json()
            if "Resources" in data:
                linked_entities[keyword] = [
                    {"uri": res["@URI"], "surfaceForm": res["@surfaceForm"]}
                    for res in data["Resources"]
                ]
        else:
            print(f"Error consultando {keyword}: {response.status_code}")
    return linked_entities

# Ejecutar la prueba
keywords = get_keywords_from_graphdb(GRAPHDB_ENDPOINT, limit=20)  # Obtener 10 palabras clave
linked_data = link_keywords_to_dbpedia(keywords, confidence=0.5)  # Enlazar con DBpedia Spotlight

# Mostrar los resultados
for keyword, entities in linked_data.items():
    print(f"\nPalabra clave: {keyword}")
    for entity in entities:
        print(f"  - DBpedia URI: {entity['uri']}")
        print(f"    Superficie relacionada: {entity['surfaceForm']}")
# Out:
# Consultando DBpedia Spotlight para: adam optimizer
# Consultando DBpedia Spotlight para: amazon product reviews
# Consultando DBpedia Spotlight para: and machine-learning algorithms
# Consultando DBpedia Spotlight para: aspect based sentiment analysis (absa)
# Consultando DBpedia Spotlight para: aspect based sentiment classification
# Consultando DBpedia Spotlight para: aspect classification
# Consultando DBpedia Spotlight para: business. economics
# Consultando DBpedia Spotlight para: ceur-ws
# Consultando DBpedia Spotlight para: classification sentiment analysis
# Consultando DBpedia Spotlight para: code-mixed dravidian language
# Consultando DBpedia Spotlight para: computational design
# Consultando DBpedia Spotlight para: convolution neural network (cnn)
# Consultando DBpedia Spotlight para: corpus-based
# Consultando DBpedia Spotlight para: customer review
# Consultando DBpedia Spotlight para: cyber threat intelligence
# Consultando DBpedia Spotlight para: cyptocurrencies
# Consultando DBpedia Spotlight para: data parsing
# Consultando DBpedia Spotlight para: deberta
# Consultando DBpedia Spotlight para: decision support systems
# Consultando DBpedia Spotlight para: decision tree method
#
# Palabra clave: aspect based sentiment analysis (absa)
#   - DBpedia URI: http://dbpedia.org/resource/Sentiment_analysis
#     Superficie relacionada: sentiment analysis
#   - DBpedia URI: http://dbpedia.org/resource/Absa_Group_Limited
#     Superficie relacionada: absa
#
# Palabra clave: classification sentiment analysis
#   - DBpedia URI: http://dbpedia.org/resource/Sentiment_analysis
#     Superficie relacionada: sentiment analysis
#
# Palabra clave: code-mixed dravidian language
#   - DBpedia URI: http://dbpedia.org/resource/Dravidian_languages
#     Superficie relacionada: dravidian language
#
# Palabra clave: convolution neural network (cnn)
#   - DBpedia URI: http://dbpedia.org/resource/Convolutional_neural_network
#     Superficie relacionada: convolution
#   - DBpedia URI: http://dbpedia.org/resource/Neural_network
#     Superficie relacionada: neural network
#   - DBpedia URI: http://dbpedia.org/resource/Convolutional_neural_network
#     Superficie relacionada: cnn
#
# Palabra clave: cyber threat intelligence
#   - DBpedia URI: http://dbpedia.org/resource/Cyber_threat_intelligence
#     Superficie relacionada: cyber threat intelligence
#
# Palabra clave: data parsing
#   - DBpedia URI: http://dbpedia.org/resource/Parsing
#     Superficie relacionada: parsing
#
# Palabra clave: decision support systems
#   - DBpedia URI: http://dbpedia.org/resource/Decision_support_system
#     Superficie relacionada: decision support
#
# Palabra clave: decision tree method
#   - DBpedia URI: http://dbpedia.org/resource/Decision_tree
#     Superficie relacionada: decision tree

# %% [markdown]
# # Extraccion de Keywords desde el TTL generado y enlazado de datos a la DBpedia

# %%
from rdflib import Graph, Namespace
import requests
import csv

# Configuración del endpoint de DBpedia Spotlight
DBPEDIA_ENDPOINT = "https://api.dbpedia-spotlight.org/en/annotate"
HEADERS = {"Accept": "application/json"}

# Cargar el archivo Turtle
TTL_FILE = "articles_data_cleaned_10.ttl"
g = Graph()
g.parse(TTL_FILE, format="turtle")

# Namespace
MYV = Namespace("http://example.org/myv/")

# Función para extraer palabras clave del archivo Turtle
def get_keywords_from_ttl(graph, limit=10):
    query = f"""
        PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
        PREFIX myv: <http://example.org/myv/>
        
        SELECT DISTINCT ?keyword
        WHERE {{
            # ?concept a skos:Concept ;
                     rdfs:label ?keyword .
        }}
        LIMIT {limit}
    """
    results = graph.query(query)
    return [str(row["keyword"]) for row in results]

# Función para consultar entidades relacionadas en DBpedia Spotlight
def link_keywords_to_dbpedia(keywords, confidence=0.5, support=20):
    linked_entities = {}
    for keyword in keywords:
        print(f"Consultando DBpedia Spotlight para: {keyword}")
        params = {
            "text": keyword,
            "confidence": confidence,
            "support": support
        }
        response = requests.get(DBPEDIA_ENDPOINT, headers=HEADERS, params=params)
        if response.status_code == 200:
            data = response.json()
            if "Resources" in data:
                linked_entities[keyword] = [
                    {"uri": res["@URI"], "surfaceForm": res["@surfaceForm"]}
                    for res in data["Resources"]
                ]
        else:
            print(f"Error consultando {keyword}: {response.status_code}")
    return linked_entities

# Función para guardar resultados en un CSV
def save_results_to_csv(linked_data, output_file="linked_keywords.csv"):
    with open(output_file, mode="w", newline="", encoding="utf-8") as file:
        writer = csv.writer(file)
        writer.writerow(["Keyword", "DBpedia URI", "Surface Form"])
        for keyword, entities in linked_data.items():
            for entity in entities:
                writer.writerow([keyword, entity["uri"], entity["surfaceForm"]])
    print(f"Resultados guardados en {output_file}")

# Ejecutar la prueba
keywords = get_keywords_from_ttl(g, limit=200)  
linked_data = link_keywords_to_dbpedia(keywords, confidence=0.5)  # Enlazar con DBpedia Spotlight

# Guardar resultados en un archivo CSV
save_results_to_csv(linked_data, output_file="linked_keywords.csv")
# Out:
# Consultando DBpedia Spotlight para: adam optimizer
# Consultando DBpedia Spotlight para: amazon product reviews
# Consultando DBpedia Spotlight para: and machine-learning algorithms
# Consultando DBpedia Spotlight para: aspect based sentiment analysis (absa)
# Consultando DBpedia Spotlight para: aspect based sentiment classification
# Consultando DBpedia Spotlight para: aspect classification
# Consultando DBpedia Spotlight para: business. economics
# Consultando DBpedia Spotlight para: ceur-ws
# Consultando DBpedia Spotlight para: classification sentiment analysis
# Consultando DBpedia Spotlight para: code-mixed dravidian language
# Consultando DBpedia Spotlight para: computational design
# Consultando DBpedia Spotlight para: convolution neural network (cnn)
# Consultando DBpedia Spotlight para: corpus-based
# Consultando DBpedia Spotlight para: customer review
# Consultando DBpedia Spotlight para: cyber threat intelligence
# Consultando DBpedia Spotlight para: cyptocurrencies
# Consultando DBpedia Spotlight para: data parsing
# Consultando DBpedia Spotlight para: deberta
# Consultando DBpedia Spotlight para: decision support systems
# Consultando DBpedia Spotlight para: decision tree method
# Consultando DBpedia Spotlight para: digital bank
# Consultando DBpedia Spotlight para: document clustering
# Consultando DBpedia Spotlight para: dravidian language
# Consultando DBpedia Spotlight para: dtc
# Consultando DBpedia Spotlight para: early depressive symptom
# Consultando DBpedia Spotlight para: early detection
# Consultando DBpedia Spotlight para: early risk detection
# Consultando DBpedia Spotlight para: election result prediction
# Consultando DBpedia Spotlight para: electric car
# Consultando DBpedia Spotlight para: entailment
# Consultando DBpedia Spotlight para: feature extraction and selection
# Consultando DBpedia Spotlight para: feedback analysis
# Consultando DBpedia Spotlight para: filipino
# Consultando DBpedia Spotlight para: financial time series forecasting
# Consultando DBpedia Spotlight para: graph similarities
# Consultando DBpedia Spotlight para: hindi-english
# Consultando DBpedia Spotlight para: homophobia
# Consultando DBpedia Spotlight para: homophobia detection
# Consultando DBpedia Spotlight para: homophobic/transphobic detection
# Consultando DBpedia Spotlight para: hybrid and ontology
# Consultando DBpedia Spotlight para: hyper-parameter tuning
# Consultando DBpedia Spotlight para: information operations
# Consultando DBpedia Spotlight para: iot
# Consultando DBpedia Spotlight para: journals
# Consultando DBpedia Spotlight para: kannada-english
# Consultando DBpedia Spotlight para: language modelling
# Consultando DBpedia Spotlight para: lexicon-based method
# Consultando DBpedia Spotlight para: lexicon-based sentiment classification
# Consultando DBpedia Spotlight para: lgbt+
# Consultando DBpedia Spotlight para: logit
# Consultando DBpedia Spotlight para: lppl
# Consultando DBpedia Spotlight para: lstm neural networks
# Consultando DBpedia Spotlight para: malayalam-english
# Consultando DBpedia Spotlight para: malaysian social media
# Consultando DBpedia Spotlight para: medical domain sentiment analysis
# Consultando DBpedia Spotlight para: mixed language
# Consultando DBpedia Spotlight para: model training
# Consultando DBpedia Spotlight para: motivation
# Consultando DBpedia Spotlight para: multi-criteria decision making
# Consultando DBpedia Spotlight para: multimodality
# Consultando DBpedia Spotlight para: neural language processing
# Consultando DBpedia Spotlight para: normalisation
# Consultando DBpedia Spotlight para: normalized google distance
# Consultando DBpedia Spotlight para: openai
# Consultando DBpedia Spotlight para: palm oil industry
# Consultando DBpedia Spotlight para: political analysis
# Consultando DBpedia Spotlight para: predictive analytics in healthcare
# Consultando DBpedia Spotlight para: random forest classification
# Consultando DBpedia Spotlight para: recursive neural tensor network
# Consultando DBpedia Spotlight para: robertuito
# Consultando DBpedia Spotlight para: robertuito model
# Consultando DBpedia Spotlight para: scrips
# Consultando DBpedia Spotlight para: self-harm
# Consultando DBpedia Spotlight para: sentiment analysis language detection
# Consultando DBpedia Spotlight para: sentiment visualisation
# Consultando DBpedia Spotlight para: sentiments analysis
# Consultando DBpedia Spotlight para: sequential bayesian linear regression (sblr)
# Consultando DBpedia Spotlight para: sexism identification
# Consultando DBpedia Spotlight para: skipgrams
# Consultando DBpedia Spotlight para: social media context
# Consultando DBpedia Spotlight para: social media intelligence
# Consultando DBpedia Spotlight para: social media text analysis
# Consultando DBpedia Spotlight para: social mining
# Consultando DBpedia Spotlight para: social monitoring
# Consultando DBpedia Spotlight para: softmax
# Consultando DBpedia Spotlight para: stochastic programming
# Consultando DBpedia Spotlight para: stock market indicators
# Consultando DBpedia Spotlight para: suicidal ideation detection
# Consultando DBpedia Spotlight para: tamil-english
# Consultando DBpedia Spotlight para: text augmentation
# Consultando DBpedia Spotlight para: text classfication
# Consultando DBpedia Spotlight para: topical stance detection
# Consultando DBpedia Spotlight para: topsis
# Consultando DBpedia Spotlight para: trademark research data
# Consultando DBpedia Spotlight para: traditional machine learning algorithms
# Consultando DBpedia Spotlight para: transliterated language
# Consultando DBpedia Spotlight para: transphobia
# Consultando DBpedia Spotlight para: trilingual
# Consultando DBpedia Spotlight para: tulu
# Consultando DBpedia Spotlight para: urban analysis
# Consultando DBpedia Spotlight para: wavelet; multi-criteria ranking
# Consultando DBpedia Spotlight para: xgboost regressor
# Consultando DBpedia Spotlight para: xlnet
# Consultando DBpedia Spotlight para: youtube comments analysis
# Consultando DBpedia Spotlight para: 1d-cnn
# Consultando DBpedia Spotlight para: 2-tuple fuzzy linguistic model
# Consultando DBpedia Spotlight para: 2020 dietary guidelines
# Consultando DBpedia Spotlight para: 2020 u.s. election
# Consultando DBpedia Spotlight para: 6g
# Consultando DBpedia Spotlight para: a social network analysis
# Consultando DBpedia Spotlight para: abilify user reviews
# Consultando DBpedia Spotlight para: absa
# Consultando DBpedia Spotlight para: abstention
# Consultando DBpedia Spotlight para: abuse
# Consultando DBpedia Spotlight para: abuse detection
# Consultando DBpedia Spotlight para: abuse words
# Consultando DBpedia Spotlight para: abusive comment
# Consultando DBpedia Spotlight para: accident detection
# Consultando DBpedia Spotlight para: accident incident
# Consultando DBpedia Spotlight para: accident prediction
# Consultando DBpedia Spotlight para: accounting
# Consultando DBpedia Spotlight para: accuracy (acc)
# Consultando DBpedia Spotlight para: accuracy analysis
# Consultando DBpedia Spotlight para: accuracy improvement
# Consultando DBpedia Spotlight para: accuracy prediction
# Consultando DBpedia Spotlight para: acf
# Consultando DBpedia Spotlight para: aco
# Consultando DBpedia Spotlight para: acquisition
# Consultando DBpedia Spotlight para: active learning-based approach
# Consultando DBpedia Spotlight para: active travel
# Consultando DBpedia Spotlight para: activity recognition
# Consultando DBpedia Spotlight para: adaboost classifier
# Consultando DBpedia Spotlight para: adaptive boosting
# Consultando DBpedia Spotlight para: adaptive instance-based learning
# Consultando DBpedia Spotlight para: adaptive self-guided filtering
# Consultando DBpedia Spotlight para: addictive
# Consultando DBpedia Spotlight para: additional key words and phrasescovid-19
# Consultando DBpedia Spotlight para: administrative burden
# Consultando DBpedia Spotlight para: adoption rates
# Consultando DBpedia Spotlight para: advances
# Consultando DBpedia Spotlight para: adversarial attack
# Consultando DBpedia Spotlight para: adversarial machine learning
# Consultando DBpedia Spotlight para: adversarial machine learning (aml)
# Consultando DBpedia Spotlight para: adversarial training
# Consultando DBpedia Spotlight para: adverse drug events
# Consultando DBpedia Spotlight para: advertisement personalization
# Consultando DBpedia Spotlight para: advocacy coalition framework
# Consultando DBpedia Spotlight para: aesthetic medicine
# Consultando DBpedia Spotlight para: affective reaction
# Consultando DBpedia Spotlight para: affin
# Consultando DBpedia Spotlight para: affinity propagation
# Consultando DBpedia Spotlight para: affront
# Consultando DBpedia Spotlight para: afghanistan
# Consultando DBpedia Spotlight para: age prediction
# Consultando DBpedia Spotlight para: ageism
# Consultando DBpedia Spotlight para: agent-based modeling
# Consultando DBpedia Spotlight para: aggressiveword
# Consultando DBpedia Spotlight para: aging
# Consultando DBpedia Spotlight para: agnipath scheme
# Consultando DBpedia Spotlight para: agri-food sector
# Consultando DBpedia Spotlight para: agriculture 4.0
# Consultando DBpedia Spotlight para: ahp
# Consultando DBpedia Spotlight para: ai-based detection systems
# Consultando DBpedia Spotlight para: ai-powered framework
# Consultando DBpedia Spotlight para: ai for healthcare
# Consultando DBpedia Spotlight para: ai global news
# Consultando DBpedia Spotlight para: ai strategies
# Consultando DBpedia Spotlight para: airline
# Consultando DBpedia Spotlight para: airline customer service
# Consultando DBpedia Spotlight para: airline data
# Consultando DBpedia Spotlight para: airline reviews
# Consultando DBpedia Spotlight para: airline sentiments
# Consultando DBpedia Spotlight para: airport service quality
# Consultando DBpedia Spotlight para: aisps
# Consultando DBpedia Spotlight para: alcohol
# Consultando DBpedia Spotlight para: alert-warning system
# Consultando DBpedia Spotlight para: algerian hirak
# Consultando DBpedia Spotlight para: algorithm
# Consultando DBpedia Spotlight para: algorithm evaluation
# Consultando DBpedia Spotlight para: allergen-specific immunotherapy
# Consultando DBpedia Spotlight para: almadar aljadid
# Consultando DBpedia Spotlight para: alspac
# Consultando DBpedia Spotlight para: altcoins
# Consultando DBpedia Spotlight para: alternative data
# Consultando DBpedia Spotlight para: alternative meat
# Consultando DBpedia Spotlight para: amazon classification
# Consultando DBpedia Spotlight para: amazon fine food reviews
# Consultando DBpedia Spotlight para: amazon rainforest
# Consultando DBpedia Spotlight para: amazon reviews data
# Consultando DBpedia Spotlight para: amazon store
# Consultando DBpedia Spotlight para: amazon web services (aws)
# Consultando DBpedia Spotlight para: ambient geographic information (agi)
# Consultando DBpedia Spotlight para: amharic text
# Consultando DBpedia Spotlight para: amplification intelligence
# Consultando DBpedia Spotlight para: ana-words
# Consultando DBpedia Spotlight para: analysing comments
# Consultando DBpedia Spotlight para: analysis
# Consultando DBpedia Spotlight para: analysis of data
# Consultando DBpedia Spotlight para: analysis opinion mining
# Consultando DBpedia Spotlight para: analysis techniques
# Resultados guardados en linked_keywords.csv

# %%
from rdflib import Graph, URIRef, Namespace, Literal
import requests
import json
from rdflib.namespace import SKOS 
# Namespaces
dbpedia = Namespace("http://dbpedia.org/resource/")
dbo = Namespace("http://dbpedia.org/ontology/")

# Configuración del endpoint de DBpedia Spotlight
DBPEDIA_SPOTLIGHT = "https://api.dbpedia-spotlight.org/en/annotate"
HEADERS = {"Accept": "application/json"}

# Función para consultar DBpedia Spotlight
def get_dbpedia_uri(keyword):
    params = {
        "text": keyword,
        "confidence": 0.5
    }
    response = requests.get(DBPEDIA_SPOTLIGHT, headers=HEADERS, params=params)
    if response.status_code == 200:
        data = response.json()
        resources = data.get("Resources", [])
        if resources:
            return resources[0]["@URI"]  # Devuelve el primer URI encontrado
    return None

# Función para consultar categorías en DBpedia
def get_dbpedia_categories(uri):
    query = f"""
    SELECT ?category WHERE {{
        <{uri}> dcterms:subject ?category .
    }}
    """
    sparql_endpoint = "http://dbpedia.org/sparql"
    params = {
        "query": query,
        "format": "json"
    }
    response = requests.get(sparql_endpoint, params=params)
    if response.status_code == 200:
        data = response.json()
        return [result["category"]["value"] for result in data["results"]["bindings"]]
    return []

# Cargar palabras clave del archivo Turtle
input_file = "articles_data_cleaned_10.ttl"
g = Graph()
g.parse(input_file, format="turtle")

# Extraer las primeras 100 palabras clave para la prueba
keywords = list(set(g.objects(None, RDFS.label)))[:100]

if keywords:
    enriched_graph = Graph()
    enriched_graph.bind("dbo", dbo)
    enriched_graph.bind("dbpedia", dbpedia)
    enriched_graph.bind("skos", SKOS)

    for keyword in keywords:
        keyword = str(keyword)
        print(f"Procesando palabra clave: {keyword}")

        # Consultar DBpedia Spotlight
        dbpedia_uri = get_dbpedia_uri(keyword)
        if dbpedia_uri:
            print(f"URI encontrado en DBpedia: {dbpedia_uri}")

            # Consultar categorías en DBpedia
            categories = get_dbpedia_categories(dbpedia_uri)
            if categories:
                print(f"Categorías encontradas para {keyword}: {categories}")

                keyword_uri = URIRef(dbpedia_uri)
                enriched_graph.add((keyword_uri, SKOS.prefLabel, Literal(keyword)))
                for category in categories:
                    enriched_graph.add((keyword_uri, dbo.category, URIRef(category)))
            else:
                print("No se encontraron categorías para la URI proporcionada.")
        else:
            print("No se encontró una URI para la palabra clave seleccionada.")

    # Guardar el resultado en un archivo RDF
    output_file = "enriched_data.ttl"
    enriched_graph.serialize(output_file, format="turtle")
    print(f"Datos enriquecidos guardados en {output_file}")
else:
    print("No se encontraron palabras clave en el archivo RDF.")
# Out:
# Procesando palabra clave: bidirection encoder representations from transformers
# No se encontró una URI para la palabra clave seleccionada.
# Procesando palabra clave: classification algorithm
# URI encontrado en DBpedia: http://dbpedia.org/resource/Algorithm
# Categorías encontradas para classification algorithm: ['http://dbpedia.org/resource/Category:Articles_with_example_pseudocode', 'http://dbpedia.org/resource/Category:Algorithms', 'http://dbpedia.org/resource/Category:Theoretical_computer_science', 'http://dbpedia.org/resource/Category:Mathematical_logic']
# Procesando palabra clave: aspect-level sentiment analysis
# URI encontrado en DBpedia: http://dbpedia.org/resource/Sentiment_analysis
# Categorías encontradas para aspect-level sentiment analysis: ['http://dbpedia.org/resource/Category:Sociology_of_technology', 'http://dbpedia.org/resource/Category:Social_information_processing', 'http://dbpedia.org/resource/Category:Social_media', 'http://dbpedia.org/resource/Category:Natural_language_processing', 'http://dbpedia.org/resource/Category:Affective_computing', 'http://dbpedia.org/resource/Category:Polling']
# Procesando palabra clave: oil sector
# No se encontró una URI para la palabra clave seleccionada.
# Procesando palabra clave: customer reviews
# No se encontró una URI para la palabra clave seleccionada.
# Procesando palabra clave: brand name
# No se encontró una URI para la palabra clave seleccionada.
# Procesando palabra clave: training
# No se encontró una URI para la palabra clave seleccionada.
# Procesando palabra clave: social media anlysis
# URI encontrado en DBpedia: http://dbpedia.org/resource/Social_media
# Categorías encontradas para social media anlysis: ['http://dbpedia.org/resource/Category:Social_media', 'http://dbpedia.org/resource/Category:Social_networks', 'http://dbpedia.org/resource/Category:Collaborative_projects']
# Procesando palabra clave: tokenisation
# URI encontrado en DBpedia: http://dbpedia.org/resource/Tokenization_(data_security)
# Categorías encontradas para tokenisation: ['http://dbpedia.org/resource/Category:Cryptography']
# Procesando palabra clave: orangutans
# No se encontró una URI para la palabra clave seleccionada.
# Procesando palabra clave: web scrapping
# No se encontró una URI para la palabra clave seleccionada.
# Procesando palabra clave: ethical considerations
# No se encontró una URI para la palabra clave seleccionada.
# Procesando palabra clave: digital forensics
# URI encontrado en DBpedia: http://dbpedia.org/resource/Digital_forensics
# Categorías encontradas para digital forensics: ['http://dbpedia.org/resource/Category:Forensic_disciplines', 'http://dbpedia.org/resource/Category:Digital_forensics']
# Procesando palabra clave: graph similarities
# URI encontrado en DBpedia: http://dbpedia.org/resource/Graph_theory
# Categorías encontradas para graph similarities: ['http://dbpedia.org/resource/Category:Graph_theory']
# Procesando palabra clave: sosyal medya
# No se encontró una URI para la palabra clave seleccionada.
# Procesando palabra clave: experimental study
# No se encontró una URI para la palabra clave seleccionada.
# Procesando palabra clave: twint
# No se encontró una URI para la palabra clave seleccionada.
# Procesando palabra clave: covid vaccines
# No se encontró una URI para la palabra clave seleccionada.
# Procesando palabra clave: data-mining framework
# URI encontrado en DBpedia: http://dbpedia.org/resource/Data_mining
# Categorías encontradas para data-mining framework: ['http://dbpedia.org/resource/Category:Formal_sciences', 'http://dbpedia.org/resource/Category:Data_mining']
# Procesando palabra clave: malay text
# No se encontró una URI para la palabra clave seleccionada.
# Procesando palabra clave: race
# No se encontró una URI para la palabra clave seleccionada.
# Procesando palabra clave: glove embedding
# No se encontró una URI para la palabra clave seleccionada.
# Procesando palabra clave: stacking
# No se encontró una URI para la palabra clave seleccionada.
# Procesando palabra clave: database technology
# URI encontrado en DBpedia: http://dbpedia.org/resource/Database
# Categorías encontradas para database technology: ['http://dbpedia.org/resource/Category:Databases', 'http://dbpedia.org/resource/Category:Database_management_systems']
# Procesando palabra clave: casablanca se
# URI encontrado en DBpedia: http://dbpedia.org/resource/Casablanca
# Categorías encontradas para casablanca se: ['http://dbpedia.org/resource/Category:Casablanca', 'http://dbpedia.org/resource/Category:Populated_places_established_in_the_7th_century_BC', 'http://dbpedia.org/resource/Category:Municipalities_of_Morocco', 'http://dbpedia.org/resource/Category:Prefecturial_capitals_in_Morocco', 'http://dbpedia.org/resource/Category:Regional_capitals_in_Morocco']
# Procesando palabra clave: sambalpuri
# URI encontrado en DBpedia: http://dbpedia.org/resource/Sambalpuri_language
# Categorías encontradas para sambalpuri: ['http://dbpedia.org/resource/Category:Odia_language', 'http://dbpedia.org/resource/Category:Languages_of_Odisha', 'http://dbpedia.org/resource/Category:Eastern_Indo-Aryan_languages']
# Procesando palabra clave: accuracy improvement
# No se encontró una URI para la palabra clave seleccionada.
# Procesando palabra clave: anomaly pattern detection
# No se encontró una URI para la palabra clave seleccionada.
# Procesando palabra clave: vaccine hesitancy
# URI encontrado en DBpedia: http://dbpedia.org/resource/Vaccine_hesitancy
# Categorías encontradas para vaccine hesitancy: ['http://dbpedia.org/resource/Category:Autism_pseudoscience', 'http://dbpedia.org/resource/Category:Articles_containing_video_clips', 'http://dbpedia.org/resource/Category:Vaccine_hesitancy', 'http://dbpedia.org/resource/Category:Medical-related_conspiracy_theories']
# Procesando palabra clave: image analysis
# URI encontrado en DBpedia: http://dbpedia.org/resource/Image_analysis
# Categorías encontradas para image analysis: ['http://dbpedia.org/resource/Category:Formal_sciences', 'http://dbpedia.org/resource/Category:Computer_vision']
# Procesando palabra clave: long short-term method
# No se encontró una URI para la palabra clave seleccionada.
# Procesando palabra clave: public discourse
# No se encontró una URI para la palabra clave seleccionada.
# Procesando palabra clave: fakes and metaphors
# No se encontró una URI para la palabra clave seleccionada.
# Procesando palabra clave: stacked bi-lstm
# No se encontró una URI para la palabra clave seleccionada.
# Procesando palabra clave: social network analysis
# URI encontrado en DBpedia: http://dbpedia.org/resource/Social_network_analysis
# Categorías encontradas para social network analysis: ['http://dbpedia.org/resource/Category:Community_building', 'http://dbpedia.org/resource/Category:Mass_media_monitoring', 'http://dbpedia.org/resource/Category:Social_systems', 'http://dbpedia.org/resource/Category:Value_(ethics)', 'http://dbpedia.org/resource/Category:Internet_culture', 'http://dbpedia.org/resource/Category:Social_information_processing', 'http://dbpedia.org/resource/Category:Types_of_analytics', 'http://dbpedia.org/resource/Category:Systems_theory', 'http://dbpedia.org/resource/Category:Methods_in_sociology', 'http://dbpedia.org/resource/Category:Social_network_analysis', 'http://dbpedia.org/resource/Category:Social_networks', 'http://dbpedia.org/resource/Category:Self-organization', 'http://dbpedia.org/resource/Category:Surveillance', 'http://dbpedia.org/resource/Category:Cultural_economics']
# Procesando palabra clave: aspect level sentiment analysis
# URI encontrado en DBpedia: http://dbpedia.org/resource/Sentiment_analysis
# Categorías encontradas para aspect level sentiment analysis: ['http://dbpedia.org/resource/Category:Sociology_of_technology', 'http://dbpedia.org/resource/Category:Social_information_processing', 'http://dbpedia.org/resource/Category:Social_media', 'http://dbpedia.org/resource/Category:Natural_language_processing', 'http://dbpedia.org/resource/Category:Affective_computing', 'http://dbpedia.org/resource/Category:Polling']
# Procesando palabra clave: extreme learning machine
# URI encontrado en DBpedia: http://dbpedia.org/resource/Extreme_learning_machine
# Categorías encontradas para extreme learning machine: ['http://dbpedia.org/resource/Category:Artificial_neural_networks']
# Procesando palabra clave: few-shot learning
# No se encontró una URI para la palabra clave seleccionada.
# Procesando palabra clave: decision tree classifier
# URI encontrado en DBpedia: http://dbpedia.org/resource/Decision_tree
# Categorías encontradas para decision tree classifier: ['http://dbpedia.org/resource/Category:Decision_analysis', 'http://dbpedia.org/resource/Category:Decision_trees']
# Procesando palabra clave: machine learning (ml)
# URI encontrado en DBpedia: http://dbpedia.org/resource/Machine_learning
# Categorías encontradas para machine learning (ml): ['http://dbpedia.org/resource/Category:Machine_learning', 'http://dbpedia.org/resource/Category:Cybernetics', 'http://dbpedia.org/resource/Category:Learning']
# Procesando palabra clave: box- office collection
# No se encontró una URI para la palabra clave seleccionada.
# Procesando palabra clave: dictionary-based approach
# No se encontró una URI para la palabra clave seleccionada.
# Procesando palabra clave: text sentiment
# No se encontró una URI para la palabra clave seleccionada.
# Procesando palabra clave: rapidminer
# URI encontrado en DBpedia: http://dbpedia.org/resource/RapidMiner
# Categorías encontradas para rapidminer: ['http://dbpedia.org/resource/Category:2022_mergers_and_acquisitions', 'http://dbpedia.org/resource/Category:Computer_vision_software', 'http://dbpedia.org/resource/Category:Data_mining_and_machine_learning_software', 'http://dbpedia.org/resource/Category:Research_and_development_in_Germany', 'http://dbpedia.org/resource/Category:Software_using_the_GNU_AGPL_license']
# Procesando palabra clave: simple recurrent neural network
# URI encontrado en DBpedia: http://dbpedia.org/resource/Neural_network
# Categorías encontradas para simple recurrent neural network: ['http://dbpedia.org/resource/Category:Artificial_intelligence', 'http://dbpedia.org/resource/Category:Emerging_technologies', 'http://dbpedia.org/resource/Category:Network_architecture', 'http://dbpedia.org/resource/Category:Neural_networks', 'http://dbpedia.org/resource/Category:Computational_neuroscience', 'http://dbpedia.org/resource/Category:Networks', 'http://dbpedia.org/resource/Category:Econometrics']
# Procesando palabra clave: arabic word2vec
# URI encontrado en DBpedia: http://dbpedia.org/resource/Word2vec
# Categorías encontradas para arabic word2vec: ['http://dbpedia.org/resource/Category:Natural_language_processing_toolkits', 'http://dbpedia.org/resource/Category:Semantic_relations', 'http://dbpedia.org/resource/Category:Machine_learning', 'http://dbpedia.org/resource/Category:Free_science_software', 'http://dbpedia.org/resource/Category:Artificial_neural_networks']
# Procesando palabra clave: basic emotions
# No se encontró una URI para la palabra clave seleccionada.
# Procesando palabra clave: organizations
# No se encontró una URI para la palabra clave seleccionada.
# Procesando palabra clave: china
# No se encontró una URI para la palabra clave seleccionada.
# Procesando palabra clave: textual analysis
# No se encontró una URI para la palabra clave seleccionada.
# Procesando palabra clave: classification
# No se encontró una URI para la palabra clave seleccionada.
# Procesando palabra clave: polarities
# No se encontró una URI para la palabra clave seleccionada.
# Procesando palabra clave: impact analysis
# No se encontró una URI para la palabra clave seleccionada.
# Procesando palabra clave: single task learning (stl)
# No se encontró una URI para la palabra clave seleccionada.
# Procesando palabra clave: alzheimer's disease
# No se encontró una URI para la palabra clave seleccionada.
# Procesando palabra clave: tweet
# No se encontró una URI para la palabra clave seleccionada.
# Procesando palabra clave: bi-gru-lstm-cnn
# No se encontró una URI para la palabra clave seleccionada.
# Procesando palabra clave: systematic literature
# No se encontró una URI para la palabra clave seleccionada.
# Procesando palabra clave: twitter application programming interface
# URI encontrado en DBpedia: http://dbpedia.org/resource/API
# Categorías encontradas para twitter application programming interface: ['http://dbpedia.org/resource/Category:Application_programming_interfaces', 'http://dbpedia.org/resource/Category:Technical_communication']
# Procesando palabra clave: tulu
# URI encontrado en DBpedia: http://dbpedia.org/resource/Tulu_language
# Categorías encontradas para tulu: ['http://dbpedia.org/resource/Category:Dravidian_languages', 'http://dbpedia.org/resource/Category:Culture_of_Kasaragod_district', 'http://dbpedia.org/resource/Category:Tulu_Nadu', 'http://dbpedia.org/resource/Category:Agglutinative_languages', 'http://dbpedia.org/resource/Category:Udupi', 'http://dbpedia.org/resource/Category:Dakshina_Kannada_district', 'http://dbpedia.org/resource/Category:Vowel-harmony_languages', 'http://dbpedia.org/resource/Category:Culture_of_Tulu_Nadu', 'http://dbpedia.org/resource/Category:Tulu_language']
# Procesando palabra clave: grounded theory
# URI encontrado en DBpedia: http://dbpedia.org/resource/Grounded_theory
# Categorías encontradas para grounded theory: ['http://dbpedia.org/resource/Category:Qualitative_research', 'http://dbpedia.org/resource/Category:Research_methods', 'http://dbpedia.org/resource/Category:Psychological_theories']
# Procesando palabra clave: online class
# No se encontró una URI para la palabra clave seleccionada.
# Procesando palabra clave: e-commerce companies
# URI encontrado en DBpedia: http://dbpedia.org/resource/E-commerce
# Categorías encontradas para e-commerce companies: ['http://dbpedia.org/resource/Category:Retail_formats', 'http://dbpedia.org/resource/Category:Electronics_industry', 'http://dbpedia.org/resource/Category:Non-store_retailing', 'http://dbpedia.org/resource/Category:Supply_chain_management', 'http://dbpedia.org/resource/Category:E-commerce']
# Procesando palabra clave: nltk
# URI encontrado en DBpedia: http://dbpedia.org/resource/Natural_Language_Toolkit
# Categorías encontradas para nltk: ['http://dbpedia.org/resource/Category:Natural_language_processing_toolkits', 'http://dbpedia.org/resource/Category:Statistical_natural_language_processing', 'http://dbpedia.org/resource/Category:Free_science_software', 'http://dbpedia.org/resource/Category:Free_software_programmed_in_Python', 'http://dbpedia.org/resource/Category:Data_analysis_software', 'http://dbpedia.org/resource/Category:Natural_language_parsing', 'http://dbpedia.org/resource/Category:Natural_language_processing', 'http://dbpedia.org/resource/Category:Python_(programming_language)_libraries', 'http://dbpedia.org/resource/Category:Free_linguistic_software']
# Procesando palabra clave: class imbalance
# No se encontró una URI para la palabra clave seleccionada.
# Procesando palabra clave: dtc
# No se encontró una URI para la palabra clave seleccionada.
# Procesando palabra clave: drugs
# No se encontró una URI para la palabra clave seleccionada.
# Procesando palabra clave: iphone
# No se encontró una URI para la palabra clave seleccionada.
# Procesando palabra clave: personality prediction
# No se encontró una URI para la palabra clave seleccionada.
# Procesando palabra clave: people's views
# No se encontró una URI para la palabra clave seleccionada.
# Procesando palabra clave: and dl
# No se encontró una URI para la palabra clave seleccionada.
# Procesando palabra clave: objectivity
# No se encontró una URI para la palabra clave seleccionada.
# Procesando palabra clave: video sentiment analysis
# URI encontrado en DBpedia: http://dbpedia.org/resource/Sentiment_analysis
# Categorías encontradas para video sentiment analysis: ['http://dbpedia.org/resource/Category:Sociology_of_technology', 'http://dbpedia.org/resource/Category:Social_information_processing', 'http://dbpedia.org/resource/Category:Social_media', 'http://dbpedia.org/resource/Category:Natural_language_processing', 'http://dbpedia.org/resource/Category:Affective_computing', 'http://dbpedia.org/resource/Category:Polling']
# Procesando palabra clave: naï ve bayes classifier
# URI encontrado en DBpedia: http://dbpedia.org/resource/Statistical_classification
# Categorías encontradas para naï ve bayes classifier: ['http://dbpedia.org/resource/Category:Classification_algorithms', 'http://dbpedia.org/resource/Category:Machine_learning', 'http://dbpedia.org/resource/Category:Statistical_classification']
# Procesando palabra clave: block chain
# No se encontró una URI para la palabra clave seleccionada.
# Procesando palabra clave: code-mixing
# URI encontrado en DBpedia: http://dbpedia.org/resource/Code-mixing
# Categorías encontradas para code-mixing: ['http://dbpedia.org/resource/Category:Education_theory', 'http://dbpedia.org/resource/Category:Human_communication', 'http://dbpedia.org/resource/Category:Syntax', 'http://dbpedia.org/resource/Category:Sociolinguistics', 'http://dbpedia.org/resource/Category:Language_acquisition', 'http://dbpedia.org/resource/Category:Linguistic_morphology', 'http://dbpedia.org/resource/Category:Psycholinguistics']
# Procesando palabra clave: natural processing language
# No se encontró una URI para la palabra clave seleccionada.
# Procesando palabra clave: unsupervised machine learning techniques
# URI encontrado en DBpedia: http://dbpedia.org/resource/Machine_learning
# Categorías encontradas para unsupervised machine learning techniques: ['http://dbpedia.org/resource/Category:Machine_learning', 'http://dbpedia.org/resource/Category:Cybernetics', 'http://dbpedia.org/resource/Category:Learning']
# Procesando palabra clave: opening mining
# No se encontró una URI para la palabra clave seleccionada.
# Procesando palabra clave: currencies
# No se encontró una URI para la palabra clave seleccionada.
# Procesando palabra clave: investor sentiment analysis
# URI encontrado en DBpedia: http://dbpedia.org/resource/Sentiment_analysis
# Categorías encontradas para investor sentiment analysis: ['http://dbpedia.org/resource/Category:Sociology_of_technology', 'http://dbpedia.org/resource/Category:Social_information_processing', 'http://dbpedia.org/resource/Category:Social_media', 'http://dbpedia.org/resource/Category:Natural_language_processing', 'http://dbpedia.org/resource/Category:Affective_computing', 'http://dbpedia.org/resource/Category:Polling']
# Procesando palabra clave: parts of speech tagging
# No se encontró una URI para la palabra clave seleccionada.
# Procesando palabra clave: cybercrime
# URI encontrado en DBpedia: http://dbpedia.org/resource/Cybercrime
# Categorías encontradas para cybercrime: ['http://dbpedia.org/resource/Category:Harassment', 'http://dbpedia.org/resource/Category:Cybercrime', 'http://dbpedia.org/resource/Category:Organized_crime_activity', 'http://dbpedia.org/resource/Category:Computer_security', 'http://dbpedia.org/resource/Category:Crime_by_type']
# Procesando palabra clave: sports industry
# URI encontrado en DBpedia: http://dbpedia.org/resource/Sport
# Categorías encontradas para sports industry: ['http://dbpedia.org/resource/Category:Sports', 'http://dbpedia.org/resource/Category:Books_about_sports', 'http://dbpedia.org/resource/Category:Main_topic_articles', 'http://dbpedia.org/resource/Category:Culture', 'http://dbpedia.org/resource/Category:Social_gatherings']
# Procesando palabra clave: chat-bot
# No se encontró una URI para la palabra clave seleccionada.
# Procesando palabra clave: snscrape
# No se encontró una URI para la palabra clave seleccionada.
# Procesando palabra clave: learning (artificial intelligence)
# URI encontrado en DBpedia: http://dbpedia.org/resource/Artificial_intelligence
# Categorías encontradas para learning (artificial intelligence): ['http://dbpedia.org/resource/Category:Artificial_intelligence', 'http://dbpedia.org/resource/Category:Emerging_technologies', 'http://dbpedia.org/resource/Category:Computational_neuroscience', 'http://dbpedia.org/resource/Category:Cybernetics', 'http://dbpedia.org/resource/Category:Formal_sciences', 'http://dbpedia.org/resource/Category:Computational_fields_of_study', 'http://dbpedia.org/resource/Category:Unsolved_problems_in_computer_science', 'http://dbpedia.org/resource/Category:Data_science']
# Procesando palabra clave: tuned-idf
# No se encontró una URI para la palabra clave seleccionada.
# Procesando palabra clave: uipath
# URI encontrado en DBpedia: http://dbpedia.org/resource/UiPath
# Categorías encontradas para uipath: ['http://dbpedia.org/resource/Category:Software_companies_based_in_New_York_City', 'http://dbpedia.org/resource/Category:Artificial_intelligence', 'http://dbpedia.org/resource/Category:Software_companies_of_the_United_States', 'http://dbpedia.org/resource/Category:Romanian_companies_established_in_2005', 'http://dbpedia.org/resource/Category:Business_software_companies', 'http://dbpedia.org/resource/Category:Companies_listed_on_the_New_York_Stock_Exchange', 'http://dbpedia.org/resource/Category:Software_companies_established_in_2005', 'http://dbpedia.org/resource/Category:2021_initial_public_offerings', 'http://dbpedia.org/resource/Category:Publicly_traded_companies_based_in_New_York_City', 'http://dbpedia.org/resource/Category:Automation_software', 'http://dbpedia.org/resource/Category:Software_companies_of_Romania']
# Procesando palabra clave: nlp - natural language processing
# URI encontrado en DBpedia: http://dbpedia.org/resource/Natural_language_processing
# Categorías encontradas para nlp - natural language processing: ['http://dbpedia.org/resource/Category:Artificial_intelligence', 'http://dbpedia.org/resource/Category:Computational_fields_of_study', 'http://dbpedia.org/resource/Category:Computational_linguistics', 'http://dbpedia.org/resource/Category:Natural_language_processing', 'http://dbpedia.org/resource/Category:Speech_recognition']
# Procesando palabra clave: estimate
# No se encontró una URI para la palabra clave seleccionada.
# Procesando palabra clave: covid19
# No se encontró una URI para la palabra clave seleccionada.
# Procesando palabra clave: transformer-based model
# No se encontró una URI para la palabra clave seleccionada.
# Procesando palabra clave: nature-inspired-algorithm
# No se encontró una URI para la palabra clave seleccionada.
# Procesando palabra clave: public complaint
# No se encontró una URI para la palabra clave seleccionada.
# Procesando palabra clave: domain adaptation
# URI encontrado en DBpedia: http://dbpedia.org/resource/Domain_adaptation
# Categorías encontradas para domain adaptation: ['http://dbpedia.org/resource/Category:Machine_learning']
# Procesando palabra clave: sentiment dataset
# No se encontró una URI para la palabra clave seleccionada.
# Procesando palabra clave: prevention
# No se encontró una URI para la palabra clave seleccionada.
# Procesando palabra clave: and technology
# No se encontró una URI para la palabra clave seleccionada.
# Procesando palabra clave: trauma
# No se encontró una URI para la palabra clave seleccionada.
# Datos enriquecidos guardados en enriched_data.ttl

# %%
for s, p, o in g.triples((None, RDFS.label, None)):
    print(s, p, o)
# Out:
# http://example.org/myv/concept/adam_optimizer http://www.w3.org/2000/01/rdf-schema#label adam optimizer
# http://example.org/myv/concept/amazon_product_reviews http://www.w3.org/2000/01/rdf-schema#label amazon product reviews
# http://example.org/myv/concept/and_machine-learning_algorithms http://www.w3.org/2000/01/rdf-schema#label and machine-learning algorithms
# http://example.org/myv/concept/aspect_based_sentiment_analysis_absa http://www.w3.org/2000/01/rdf-schema#label aspect based sentiment analysis (absa)
# http://example.org/myv/concept/aspect_based_sentiment_classification http://www.w3.org/2000/01/rdf-schema#label aspect based sentiment classification
# http://example.org/myv/concept/aspect_classification http://www.w3.org/2000/01/rdf-schema#label aspect classification
# http://example.org/myv/concept/business_economics http://www.w3.org/2000/01/rdf-schema#label business. economics
# http://example.org/myv/concept/ceur-ws http://www.w3.org/2000/01/rdf-schema#label ceur-ws
# http://example.org/myv/concept/classification_sentiment_analysis http://www.w3.org/2000/01/rdf-schema#label classification sentiment analysis
# http://example.org/myv/concept/code-mixed_dravidian_language http://www.w3.org/2000/01/rdf-schema#label code-mixed dravidian language
# http://example.org/myv/concept/computational_design http://www.w3.org/2000/01/rdf-schema#label computational design
# http://example.org/myv/concept/convolution_neural_network_cnn http://www.w3.org/2000/01/rdf-schema#label convolution neural network (cnn)
# http://example.org/myv/concept/corpus-based http://www.w3.org/2000/01/rdf-schema#label corpus-based
# http://example.org/myv/concept/customer_review http://www.w3.org/2000/01/rdf-schema#label customer review
# http://example.org/myv/concept/cyber_threat_intelligence http://www.w3.org/2000/01/rdf-schema#label cyber threat intelligence
# http://example.org/myv/concept/cyptocurrencies http://www.w3.org/2000/01/rdf-schema#label cyptocurrencies
# http://example.org/myv/concept/data_parsing http://www.w3.org/2000/01/rdf-schema#label data parsing
# http://example.org/myv/concept/deberta http://www.w3.org/2000/01/rdf-schema#label deberta
# http://example.org/myv/concept/decision_support_systems http://www.w3.org/2000/01/rdf-schema#label decision support systems
# http://example.org/myv/concept/decision_tree_method http://www.w3.org/2000/01/rdf-schema#label decision tree method
# http://example.org/myv/concept/digital_bank http://www.w3.org/2000/01/rdf-schema#label digital bank
# http://example.org/myv/concept/document_clustering http://www.w3.org/2000/01/rdf-schema#label document clustering
# http://example.org/myv/concept/dravidian_language http://www.w3.org/2000/01/rdf-schema#label dravidian language
# http://example.org/myv/concept/dtc http://www.w3.org/2000/01/rdf-schema#label dtc
# http://example.org/myv/concept/early_depressive_symptom http://www.w3.org/2000/01/rdf-schema#label early depressive symptom
# http://example.org/myv/concept/early_detection http://www.w3.org/2000/01/rdf-schema#label early detection
# http://example.org/myv/concept/early_risk_detection http://www.w3.org/2000/01/rdf-schema#label early risk detection
# http://example.org/myv/concept/election_result_prediction http://www.w3.org/2000/01/rdf-schema#label election result prediction
# http://example.org/myv/concept/electric_car http://www.w3.org/2000/01/rdf-schema#label electric car
# http://example.org/myv/concept/entailment http://www.w3.org/2000/01/rdf-schema#label entailment
# http://example.org/myv/concept/feature_extraction_and_selection http://www.w3.org/2000/01/rdf-schema#label feature extraction and selection
# http://example.org/myv/concept/feedback_analysis http://www.w3.org/2000/01/rdf-schema#label feedback analysis
# http://example.org/myv/concept/filipino http://www.w3.org/2000/01/rdf-schema#label filipino
# http://example.org/myv/concept/financial_time_series_forecasting http://www.w3.org/2000/01/rdf-schema#label financial time series forecasting
# http://example.org/myv/concept/graph_similarities http://www.w3.org/2000/01/rdf-schema#label graph similarities
# http://example.org/myv/concept/hindi-english http://www.w3.org/2000/01/rdf-schema#label hindi-english
# http://example.org/myv/concept/homophobia http://www.w3.org/2000/01/rdf-schema#label homophobia
# http://example.org/myv/concept/homophobia_detection http://www.w3.org/2000/01/rdf-schema#label homophobia detection
# http://example.org/myv/concept/homophobictransphobic_detection http://www.w3.org/2000/01/rdf-schema#label homophobic/transphobic detection
# http://example.org/myv/concept/hybrid_and_ontology http://www.w3.org/2000/01/rdf-schema#label hybrid and ontology
# http://example.org/myv/concept/hyper-parameter_tuning http://www.w3.org/2000/01/rdf-schema#label hyper-parameter tuning
# http://example.org/myv/concept/information_operations http://www.w3.org/2000/01/rdf-schema#label information operations
# http://example.org/myv/concept/iot http://www.w3.org/2000/01/rdf-schema#label iot
# http://example.org/myv/concept/journals http://www.w3.org/2000/01/rdf-schema#label journals
# http://example.org/myv/concept/kannada-english http://www.w3.org/2000/01/rdf-schema#label kannada-english
# http://example.org/myv/concept/language_modelling http://www.w3.org/2000/01/rdf-schema#label language modelling
# http://example.org/myv/concept/lexicon-based_method http://www.w3.org/2000/01/rdf-schema#label lexicon-based method
# http://example.org/myv/concept/lexicon-based_sentiment_classification http://www.w3.org/2000/01/rdf-schema#label lexicon-based sentiment classification
# http://example.org/myv/concept/lgbt http://www.w3.org/2000/01/rdf-schema#label lgbt+
# http://example.org/myv/concept/logit http://www.w3.org/2000/01/rdf-schema#label logit
# http://example.org/myv/concept/lppl http://www.w3.org/2000/01/rdf-schema#label lppl
# http://example.org/myv/concept/lstm_neural_networks http://www.w3.org/2000/01/rdf-schema#label lstm neural networks
# http://example.org/myv/concept/malayalam-english http://www.w3.org/2000/01/rdf-schema#label malayalam-english
# http://example.org/myv/concept/malaysian_social_media http://www.w3.org/2000/01/rdf-schema#label malaysian social media
# http://example.org/myv/concept/medical_domain_sentiment_analysis http://www.w3.org/2000/01/rdf-schema#label medical domain sentiment analysis
# http://example.org/myv/concept/mixed_language http://www.w3.org/2000/01/rdf-schema#label mixed language
# http://example.org/myv/concept/model_training http://www.w3.org/2000/01/rdf-schema#label model training
# http://example.org/myv/concept/motivation http://www.w3.org/2000/01/rdf-schema#label motivation
# http://example.org/myv/concept/multi-criteria_decision_making http://www.w3.org/2000/01/rdf-schema#label multi-criteria decision making
# http://example.org/myv/concept/multimodality http://www.w3.org/2000/01/rdf-schema#label multimodality
# http://example.org/myv/concept/neural_language_processing http://www.w3.org/2000/01/rdf-schema#label neural language processing
# http://example.org/myv/concept/normalisation http://www.w3.org/2000/01/rdf-schema#label normalisation
# http://example.org/myv/concept/normalized_google_distance http://www.w3.org/2000/01/rdf-schema#label normalized google distance
# http://example.org/myv/concept/openai http://www.w3.org/2000/01/rdf-schema#label openai
# http://example.org/myv/concept/palm_oil_industry http://www.w3.org/2000/01/rdf-schema#label palm oil industry
# http://example.org/myv/concept/political_analysis http://www.w3.org/2000/01/rdf-schema#label political analysis
# http://example.org/myv/concept/predictive_analytics_in_healthcare http://www.w3.org/2000/01/rdf-schema#label predictive analytics in healthcare
# http://example.org/myv/concept/random_forest_classification http://www.w3.org/2000/01/rdf-schema#label random forest classification
# http://example.org/myv/concept/recursive_neural_tensor_network http://www.w3.org/2000/01/rdf-schema#label recursive neural tensor network
# http://example.org/myv/concept/robertuito http://www.w3.org/2000/01/rdf-schema#label robertuito
# http://example.org/myv/concept/robertuito_model http://www.w3.org/2000/01/rdf-schema#label robertuito model
# http://example.org/myv/concept/scrips http://www.w3.org/2000/01/rdf-schema#label scrips
# http://example.org/myv/concept/self-harm http://www.w3.org/2000/01/rdf-schema#label self-harm
# http://example.org/myv/concept/sentiment_analysis_language_detection http://www.w3.org/2000/01/rdf-schema#label sentiment analysis language detection
# http://example.org/myv/concept/sentiment_visualisation http://www.w3.org/2000/01/rdf-schema#label sentiment visualisation
# http://example.org/myv/concept/sentiments_analysis http://www.w3.org/2000/01/rdf-schema#label sentiments analysis
# http://example.org/myv/concept/sequential_bayesian_linear_regression_sblr http://www.w3.org/2000/01/rdf-schema#label sequential bayesian linear regression (sblr)
# http://example.org/myv/concept/sexism_identification http://www.w3.org/2000/01/rdf-schema#label sexism identification
# http://example.org/myv/concept/skipgrams http://www.w3.org/2000/01/rdf-schema#label skipgrams
# http://example.org/myv/concept/social_media_context http://www.w3.org/2000/01/rdf-schema#label social media context
# http://example.org/myv/concept/social_media_intelligence http://www.w3.org/2000/01/rdf-schema#label social media intelligence
# http://example.org/myv/concept/social_media_text_analysis http://www.w3.org/2000/01/rdf-schema#label social media text analysis
# http://example.org/myv/concept/social_mining http://www.w3.org/2000/01/rdf-schema#label social mining
# http://example.org/myv/concept/social_monitoring http://www.w3.org/2000/01/rdf-schema#label social monitoring
# http://example.org/myv/concept/softmax http://www.w3.org/2000/01/rdf-schema#label softmax
# http://example.org/myv/concept/stochastic_programming http://www.w3.org/2000/01/rdf-schema#label stochastic programming
# http://example.org/myv/concept/stock_market_indicators http://www.w3.org/2000/01/rdf-schema#label stock market indicators
# http://example.org/myv/concept/suicidal_ideation_detection http://www.w3.org/2000/01/rdf-schema#label suicidal ideation detection
# http://example.org/myv/concept/tamil-english http://www.w3.org/2000/01/rdf-schema#label tamil-english
# http://example.org/myv/concept/text_augmentation http://www.w3.org/2000/01/rdf-schema#label text augmentation
# http://example.org/myv/concept/text_classfication http://www.w3.org/2000/01/rdf-schema#label text classfication
# http://example.org/myv/concept/topical_stance_detection http://www.w3.org/2000/01/rdf-schema#label topical stance detection
# http://example.org/myv/concept/topsis http://www.w3.org/2000/01/rdf-schema#label topsis
# http://example.org/myv/concept/trademark_research_data http://www.w3.org/2000/01/rdf-schema#label trademark research data
# http://example.org/myv/concept/traditional_machine_learning_algorithms http://www.w3.org/2000/01/rdf-schema#label traditional machine learning algorithms
# http://example.org/myv/concept/transliterated_language http://www.w3.org/2000/01/rdf-schema#label transliterated language
# http://example.org/myv/concept/transphobia http://www.w3.org/2000/01/rdf-schema#label transphobia
# http://example.org/myv/concept/trilingual http://www.w3.org/2000/01/rdf-schema#label trilingual
# http://example.org/myv/concept/tulu http://www.w3.org/2000/01/rdf-schema#label tulu
# http://example.org/myv/concept/urban_analysis http://www.w3.org/2000/01/rdf-schema#label urban analysis
# http://example.org/myv/concept/wavelet_multi-criteria_ranking http://www.w3.org/2000/01/rdf-schema#label wavelet; multi-criteria ranking
# http://example.org/myv/concept/xgboost_regressor http://www.w3.org/2000/01/rdf-schema#label xgboost regressor
# http://example.org/myv/concept/xlnet http://www.w3.org/2000/01/rdf-schema#label xlnet
# http://example.org/myv/concept/youtube_comments_analysis http://www.w3.org/2000/01/rdf-schema#label youtube comments analysis
# http://example.org/myv/concept/1d-cnn http://www.w3.org/2000/01/rdf-schema#label 1d-cnn
# http://example.org/myv/concept/2-tuple_fuzzy_linguistic_model http://www.w3.org/2000/01/rdf-schema#label 2-tuple fuzzy linguistic model
# http://example.org/myv/concept/2020_dietary_guidelines http://www.w3.org/2000/01/rdf-schema#label 2020 dietary guidelines
# http://example.org/myv/concept/2020_us_election http://www.w3.org/2000/01/rdf-schema#label 2020 u.s. election
# http://example.org/myv/concept/6g http://www.w3.org/2000/01/rdf-schema#label 6g
# http://example.org/myv/concept/a_social_network_analysis http://www.w3.org/2000/01/rdf-schema#label a social network analysis
# http://example.org/myv/concept/abilify_user_reviews http://www.w3.org/2000/01/rdf-schema#label abilify user reviews
# http://example.org/myv/concept/absa http://www.w3.org/2000/01/rdf-schema#label absa
# http://example.org/myv/concept/abstention http://www.w3.org/2000/01/rdf-schema#label abstention
# http://example.org/myv/concept/abuse http://www.w3.org/2000/01/rdf-schema#label abuse
# http://example.org/myv/concept/abuse_detection http://www.w3.org/2000/01/rdf-schema#label abuse detection
# http://example.org/myv/concept/abuse_words http://www.w3.org/2000/01/rdf-schema#label abuse words
# http://example.org/myv/concept/abusive_comment http://www.w3.org/2000/01/rdf-schema#label abusive comment
# http://example.org/myv/concept/accident_detection http://www.w3.org/2000/01/rdf-schema#label accident detection
# http://example.org/myv/concept/accident_incident http://www.w3.org/2000/01/rdf-schema#label accident incident
# http://example.org/myv/concept/accident_prediction http://www.w3.org/2000/01/rdf-schema#label accident prediction
# http://example.org/myv/concept/accounting http://www.w3.org/2000/01/rdf-schema#label accounting
# http://example.org/myv/concept/accuracy_acc http://www.w3.org/2000/01/rdf-schema#label accuracy (acc)
# http://example.org/myv/concept/accuracy_analysis http://www.w3.org/2000/01/rdf-schema#label accuracy analysis
# http://example.org/myv/concept/accuracy_improvement http://www.w3.org/2000/01/rdf-schema#label accuracy improvement
# http://example.org/myv/concept/accuracy_prediction http://www.w3.org/2000/01/rdf-schema#label accuracy prediction
# http://example.org/myv/concept/acf http://www.w3.org/2000/01/rdf-schema#label acf
# http://example.org/myv/concept/aco http://www.w3.org/2000/01/rdf-schema#label aco
# http://example.org/myv/concept/acquisition http://www.w3.org/2000/01/rdf-schema#label acquisition
# http://example.org/myv/concept/active_learning-based_approach http://www.w3.org/2000/01/rdf-schema#label active learning-based approach
# http://example.org/myv/concept/active_travel http://www.w3.org/2000/01/rdf-schema#label active travel
# http://example.org/myv/concept/activity_recognition http://www.w3.org/2000/01/rdf-schema#label activity recognition
# http://example.org/myv/concept/adaboost_classifier http://www.w3.org/2000/01/rdf-schema#label adaboost classifier
# http://example.org/myv/concept/adaptive_boosting http://www.w3.org/2000/01/rdf-schema#label adaptive boosting
# http://example.org/myv/concept/adaptive_instance-based_learning http://www.w3.org/2000/01/rdf-schema#label adaptive instance-based learning
# http://example.org/myv/concept/adaptive_self-guided_filtering http://www.w3.org/2000/01/rdf-schema#label adaptive self-guided filtering
# http://example.org/myv/concept/addictive http://www.w3.org/2000/01/rdf-schema#label addictive
# http://example.org/myv/concept/additional_key_words_and_phrasescovid-19 http://www.w3.org/2000/01/rdf-schema#label additional key words and phrasescovid-19
# http://example.org/myv/concept/administrative_burden http://www.w3.org/2000/01/rdf-schema#label administrative burden
# http://example.org/myv/concept/adoption_rates http://www.w3.org/2000/01/rdf-schema#label adoption rates
# http://example.org/myv/concept/advances http://www.w3.org/2000/01/rdf-schema#label advances
# http://example.org/myv/concept/adversarial_attack http://www.w3.org/2000/01/rdf-schema#label adversarial attack
# http://example.org/myv/concept/adversarial_machine_learning http://www.w3.org/2000/01/rdf-schema#label adversarial machine learning
# http://example.org/myv/concept/adversarial_machine_learning_aml http://www.w3.org/2000/01/rdf-schema#label adversarial machine learning (aml)
# http://example.org/myv/concept/adversarial_training http://www.w3.org/2000/01/rdf-schema#label adversarial training
# http://example.org/myv/concept/adverse_drug_events http://www.w3.org/2000/01/rdf-schema#label adverse drug events
# http://example.org/myv/concept/advertisement_personalization http://www.w3.org/2000/01/rdf-schema#label advertisement personalization
# http://example.org/myv/concept/advocacy_coalition_framework http://www.w3.org/2000/01/rdf-schema#label advocacy coalition framework
# http://example.org/myv/concept/aesthetic_medicine http://www.w3.org/2000/01/rdf-schema#label aesthetic medicine
# http://example.org/myv/concept/affective_reaction http://www.w3.org/2000/01/rdf-schema#label affective reaction
# http://example.org/myv/concept/affin http://www.w3.org/2000/01/rdf-schema#label affin
# http://example.org/myv/concept/affinity_propagation http://www.w3.org/2000/01/rdf-schema#label affinity propagation
# http://example.org/myv/concept/affront http://www.w3.org/2000/01/rdf-schema#label affront
# http://example.org/myv/concept/afghanistan http://www.w3.org/2000/01/rdf-schema#label afghanistan
# http://example.org/myv/concept/age_prediction http://www.w3.org/2000/01/rdf-schema#label age prediction
# http://example.org/myv/concept/ageism http://www.w3.org/2000/01/rdf-schema#label ageism
# http://example.org/myv/concept/agent-based_modeling http://www.w3.org/2000/01/rdf-schema#label agent-based modeling
# http://example.org/myv/concept/aggressiveword http://www.w3.org/2000/01/rdf-schema#label aggressiveword
# http://example.org/myv/concept/aging http://www.w3.org/2000/01/rdf-schema#label aging
# http://example.org/myv/concept/agnipath_scheme http://www.w3.org/2000/01/rdf-schema#label agnipath scheme
# http://example.org/myv/concept/agri-food_sector http://www.w3.org/2000/01/rdf-schema#label agri-food sector
# http://example.org/myv/concept/agriculture_40 http://www.w3.org/2000/01/rdf-schema#label agriculture 4.0
# http://example.org/myv/concept/ahp http://www.w3.org/2000/01/rdf-schema#label ahp
# http://example.org/myv/concept/ai-based_detection_systems http://www.w3.org/2000/01/rdf-schema#label ai-based detection systems
# http://example.org/myv/concept/ai-powered_framework http://www.w3.org/2000/01/rdf-schema#label ai-powered framework
# http://example.org/myv/concept/ai_for_healthcare http://www.w3.org/2000/01/rdf-schema#label ai for healthcare
# http://example.org/myv/concept/ai_global_news http://www.w3.org/2000/01/rdf-schema#label ai global news
# http://example.org/myv/concept/ai_strategies http://www.w3.org/2000/01/rdf-schema#label ai strategies
# http://example.org/myv/concept/airline http://www.w3.org/2000/01/rdf-schema#label airline
# http://example.org/myv/concept/airline_customer_service http://www.w3.org/2000/01/rdf-schema#label airline customer service
# http://example.org/myv/concept/airline_data http://www.w3.org/2000/01/rdf-schema#label airline data
# http://example.org/myv/concept/airline_reviews http://www.w3.org/2000/01/rdf-schema#label airline reviews
# http://example.org/myv/concept/airline_sentiments http://www.w3.org/2000/01/rdf-schema#label airline sentiments
# http://example.org/myv/concept/airport_service_quality http://www.w3.org/2000/01/rdf-schema#label airport service quality
# http://example.org/myv/concept/aisps http://www.w3.org/2000/01/rdf-schema#label aisps
# http://example.org/myv/concept/alcohol http://www.w3.org/2000/01/rdf-schema#label alcohol
# http://example.org/myv/concept/alert-warning_system http://www.w3.org/2000/01/rdf-schema#label alert-warning system
# http://example.org/myv/concept/algerian_hirak http://www.w3.org/2000/01/rdf-schema#label algerian hirak
# http://example.org/myv/concept/algorithm http://www.w3.org/2000/01/rdf-schema#label algorithm
# http://example.org/myv/concept/algorithm_evaluation http://www.w3.org/2000/01/rdf-schema#label algorithm evaluation
# http://example.org/myv/concept/allergen-specific_immunotherapy http://www.w3.org/2000/01/rdf-schema#label allergen-specific immunotherapy
# http://example.org/myv/concept/almadar_aljadid http://www.w3.org/2000/01/rdf-schema#label almadar aljadid
# http://example.org/myv/concept/alspac http://www.w3.org/2000/01/rdf-schema#label alspac
# http://example.org/myv/concept/altcoins http://www.w3.org/2000/01/rdf-schema#label altcoins
# http://example.org/myv/concept/alternative_data http://www.w3.org/2000/01/rdf-schema#label alternative data
# http://example.org/myv/concept/alternative_meat http://www.w3.org/2000/01/rdf-schema#label alternative meat
# http://example.org/myv/concept/amazon_classification http://www.w3.org/2000/01/rdf-schema#label amazon classification
# http://example.org/myv/concept/amazon_fine_food_reviews http://www.w3.org/2000/01/rdf-schema#label amazon fine food reviews
# http://example.org/myv/concept/amazon_rainforest http://www.w3.org/2000/01/rdf-schema#label amazon rainforest
# http://example.org/myv/concept/amazon_reviews_data http://www.w3.org/2000/01/rdf-schema#label amazon reviews data
# http://example.org/myv/concept/amazon_store http://www.w3.org/2000/01/rdf-schema#label amazon store
# http://example.org/myv/concept/amazon_web_services_aws http://www.w3.org/2000/01/rdf-schema#label amazon web services (aws)
# http://example.org/myv/concept/ambient_geographic_information_agi http://www.w3.org/2000/01/rdf-schema#label ambient geographic information (agi)
# http://example.org/myv/concept/amharic_text http://www.w3.org/2000/01/rdf-schema#label amharic text
# http://example.org/myv/concept/amplification_intelligence http://www.w3.org/2000/01/rdf-schema#label amplification intelligence
# http://example.org/myv/concept/ana-words http://www.w3.org/2000/01/rdf-schema#label ana-words
# http://example.org/myv/concept/analysing_comments http://www.w3.org/2000/01/rdf-schema#label analysing comments
# http://example.org/myv/concept/analysis http://www.w3.org/2000/01/rdf-schema#label analysis
# http://example.org/myv/concept/analysis_of_data http://www.w3.org/2000/01/rdf-schema#label analysis of data
# http://example.org/myv/concept/analysis_opinion_mining http://www.w3.org/2000/01/rdf-schema#label analysis opinion mining
# http://example.org/myv/concept/analysis_techniques http://www.w3.org/2000/01/rdf-schema#label analysis techniques
# http://example.org/myv/concept/analytic_hierarchy_process http://www.w3.org/2000/01/rdf-schema#label analytic hierarchy process
# http://example.org/myv/concept/analytical_hierarchical_process_ahp http://www.w3.org/2000/01/rdf-schema#label analytical hierarchical process (ahp)
# http://example.org/myv/concept/analytical_hierarchy_process http://www.w3.org/2000/01/rdf-schema#label analytical hierarchy process
# http://example.org/myv/concept/analytical_models http://www.w3.org/2000/01/rdf-schema#label analytical models
# http://example.org/myv/concept/analytics http://www.w3.org/2000/01/rdf-schema#label analytics
# http://example.org/myv/concept/analytics_platforms http://www.w3.org/2000/01/rdf-schema#label analytics platforms
# http://example.org/myv/concept/analyze http://www.w3.org/2000/01/rdf-schema#label analyze
# http://example.org/myv/concept/analyze_public_sentiment http://www.w3.org/2000/01/rdf-schema#label analyze public sentiment
# http://example.org/myv/concept/anaphora_resolution http://www.w3.org/2000/01/rdf-schema#label anaphora resolution
# http://example.org/myv/concept/and_attention-based_bilateral_long_short-term_memory_cnn http://www.w3.org/2000/01/rdf-schema#label and attention-based bilateral long short-term memory cnn
# http://example.org/myv/concept/and_cbrnn http://www.w3.org/2000/01/rdf-schema#label and cbrnn
# http://example.org/myv/concept/and_deep_learning_models http://www.w3.org/2000/01/rdf-schema#label and deep learning models
# http://example.org/myv/concept/and_dl http://www.w3.org/2000/01/rdf-schema#label and dl
# http://example.org/myv/concept/and_lexical_tools http://www.w3.org/2000/01/rdf-schema#label and lexical tools
# http://example.org/myv/concept/and_machine_learning http://www.w3.org/2000/01/rdf-schema#label and machine learning
# http://example.org/myv/concept/and_privacy_protection http://www.w3.org/2000/01/rdf-schema#label and privacy protection
# http://example.org/myv/concept/and_technology http://www.w3.org/2000/01/rdf-schema#label and technology
# http://example.org/myv/concept/anger http://www.w3.org/2000/01/rdf-schema#label anger
# http://example.org/myv/concept/ann_classification http://www.w3.org/2000/01/rdf-schema#label ann classification
# http://example.org/myv/concept/annotated_corpus http://www.w3.org/2000/01/rdf-schema#label annotated corpus
# http://example.org/myv/concept/anns http://www.w3.org/2000/01/rdf-schema#label anns
# http://example.org/myv/concept/anomaly_pattern_detection http://www.w3.org/2000/01/rdf-schema#label anomaly pattern detection
# http://example.org/myv/concept/ant_lion_optimization_alo http://www.w3.org/2000/01/rdf-schema#label ant lion optimization (alo)
# http://example.org/myv/concept/anti-asian http://www.w3.org/2000/01/rdf-schema#label anti-asian
# http://example.org/myv/concept/anti-pancasila http://www.w3.org/2000/01/rdf-schema#label anti-pancasila
# http://example.org/myv/concept/anti-vaccination http://www.w3.org/2000/01/rdf-schema#label anti-vaccination
# http://example.org/myv/concept/anti-vaccine_sentiment http://www.w3.org/2000/01/rdf-schema#label anti-vaccine sentiment
# http://example.org/myv/concept/anti-vax http://www.w3.org/2000/01/rdf-schema#label anti-vax
# http://example.org/myv/concept/antivaccination_movement http://www.w3.org/2000/01/rdf-schema#label antivaccination movement
# http://example.org/myv/concept/anxiety_disorder http://www.w3.org/2000/01/rdf-schema#label anxiety disorder
# http://example.org/myv/concept/anxiety_level http://www.w3.org/2000/01/rdf-schema#label anxiety level
# http://example.org/myv/concept/apache_flume http://www.w3.org/2000/01/rdf-schema#label apache flume
# http://example.org/myv/concept/apache_hive http://www.w3.org/2000/01/rdf-schema#label apache hive
# http://example.org/myv/concept/api_appli-cation_programming_interface http://www.w3.org/2000/01/rdf-schema#label api (appli-cation programming interface)
# http://example.org/myv/concept/api_facilities http://www.w3.org/2000/01/rdf-schema#label api facilities
# http://example.org/myv/concept/app-based_food_companies http://www.w3.org/2000/01/rdf-schema#label app-based food companies
# http://example.org/myv/concept/app_reviewers http://www.w3.org/2000/01/rdf-schema#label app reviewers
# http://example.org/myv/concept/application_of_existing_datasets http://www.w3.org/2000/01/rdf-schema#label application of existing datasets
# http://example.org/myv/concept/application_programming_interface_api http://www.w3.org/2000/01/rdf-schema#label application programming interface (api)
# http://example.org/myv/concept/approaches http://www.w3.org/2000/01/rdf-schema#label approaches
# http://example.org/myv/concept/aquila_optimization_algorithm http://www.w3.org/2000/01/rdf-schema#label aquila optimization algorithm
# http://example.org/myv/concept/arab_media http://www.w3.org/2000/01/rdf-schema#label arab media
# http://example.org/myv/concept/arab_social_media http://www.w3.org/2000/01/rdf-schema#label arab social media
# http://example.org/myv/concept/arabic-language_tweets http://www.w3.org/2000/01/rdf-schema#label arabic-language tweets
# http://example.org/myv/concept/arabic_data_annotation http://www.w3.org/2000/01/rdf-schema#label arabic data annotation
# http://example.org/myv/concept/arabic_dataset http://www.w3.org/2000/01/rdf-schema#label arabic dataset
# http://example.org/myv/concept/arabic_language_and_dialects http://www.w3.org/2000/01/rdf-schema#label arabic language and dialects
# http://example.org/myv/concept/arabic_language_processing http://www.w3.org/2000/01/rdf-schema#label arabic language processing
# http://example.org/myv/concept/arabic_language_sentiment http://www.w3.org/2000/01/rdf-schema#label arabic language sentiment
# http://example.org/myv/concept/arabic_moroccan_dialect http://www.w3.org/2000/01/rdf-schema#label arabic moroccan dialect
# http://example.org/myv/concept/arabic_news http://www.w3.org/2000/01/rdf-schema#label arabic news
# http://example.org/myv/concept/arabic_political_article http://www.w3.org/2000/01/rdf-schema#label arabic political article
# http://example.org/myv/concept/arabic_sarcasm_detection http://www.w3.org/2000/01/rdf-schema#label arabic sarcasm detection
# http://example.org/myv/concept/arabic_sentiment_analysis_asa http://www.w3.org/2000/01/rdf-schema#label arabic sentiment analysis (asa)
# http://example.org/myv/concept/arabic_text_mining http://www.w3.org/2000/01/rdf-schema#label arabic text mining
# http://example.org/myv/concept/arabic_tweets_deep_learning http://www.w3.org/2000/01/rdf-schema#label arabic tweets, deep learning
# http://example.org/myv/concept/arabic_word2vec http://www.w3.org/2000/01/rdf-schema#label arabic word2vec
# http://example.org/myv/concept/aravec http://www.w3.org/2000/01/rdf-schema#label aravec
# http://example.org/myv/concept/aravec_word_embedding http://www.w3.org/2000/01/rdf-schema#label aravec word embedding
# http://example.org/myv/concept/argentina http://www.w3.org/2000/01/rdf-schema#label argentina
# http://example.org/myv/concept/arlstem http://www.w3.org/2000/01/rdf-schema#label arlstem
# http://example.org/myv/concept/aroc http://www.w3.org/2000/01/rdf-schema#label aroc
# http://example.org/myv/concept/arousal http://www.w3.org/2000/01/rdf-schema#label arousal
# http://example.org/myv/concept/artificial_fish_swarm_algorithm http://www.w3.org/2000/01/rdf-schema#label artificial fish swarm algorithm
# http://example.org/myv/concept/artificial_intelligence_ai_machine_learning http://www.w3.org/2000/01/rdf-schema#label artificial intelligence (ai), machine learning
# http://example.org/myv/concept/artificial_intelligence_methods http://www.w3.org/2000/01/rdf-schema#label artificial intelligence methods
# http://example.org/myv/concept/artificial_intelligence_on_global_events http://www.w3.org/2000/01/rdf-schema#label artificial intelligence on global events
# http://example.org/myv/concept/artificial_intelligenceai http://www.w3.org/2000/01/rdf-schema#label artificial intelligence(ai)
# http://example.org/myv/concept/artificial_intelligent http://www.w3.org/2000/01/rdf-schema#label artificial intelligent
# http://example.org/myv/concept/artificial_intelligent_ai http://www.w3.org/2000/01/rdf-schema#label artificial intelligent (ai)
# http://example.org/myv/concept/artificial_neural_networkann http://www.w3.org/2000/01/rdf-schema#label artificial neural network(ann)
# http://example.org/myv/concept/asd http://www.w3.org/2000/01/rdf-schema#label asd
# http://example.org/myv/concept/aspect http://www.w3.org/2000/01/rdf-schema#label aspect
# http://example.org/myv/concept/aspect-based_emotion_analysis http://www.w3.org/2000/01/rdf-schema#label aspect-based emotion analysis
# http://example.org/myv/concept/aspect-level_sentiment_analysis http://www.w3.org/2000/01/rdf-schema#label aspect-level sentiment analysis
# http://example.org/myv/concept/aspect_extraction http://www.w3.org/2000/01/rdf-schema#label aspect extraction
# http://example.org/myv/concept/aspect_learning-based_method http://www.w3.org/2000/01/rdf-schema#label aspect learning-based method
# http://example.org/myv/concept/aspect_level_sentiment_analysis http://www.w3.org/2000/01/rdf-schema#label aspect level sentiment analysis
# http://example.org/myv/concept/aspect_sentiment_analysis http://www.w3.org/2000/01/rdf-schema#label aspect sentiment analysis
# http://example.org/myv/concept/assamese_language http://www.w3.org/2000/01/rdf-schema#label assamese language
# http://example.org/myv/concept/assessment http://www.w3.org/2000/01/rdf-schema#label assessment
# http://example.org/myv/concept/assetization http://www.w3.org/2000/01/rdf-schema#label assetization
# http://example.org/myv/concept/assistive_technology http://www.w3.org/2000/01/rdf-schema#label assistive technology
# http://example.org/myv/concept/association_rules http://www.w3.org/2000/01/rdf-schema#label association rules
# http://example.org/myv/concept/asymmetry_effect http://www.w3.org/2000/01/rdf-schema#label asymmetry effect
# http://example.org/myv/concept/athletic_performance http://www.w3.org/2000/01/rdf-schema#label athletic performance
# http://example.org/myv/concept/atmosphere http://www.w3.org/2000/01/rdf-schema#label atmosphere
# http://example.org/myv/concept/attention-based_bilstm http://www.w3.org/2000/01/rdf-schema#label attention-based bilstm
# http://example.org/myv/concept/attention-based_models http://www.w3.org/2000/01/rdf-schema#label attention-based models
# http://example.org/myv/concept/attention_layer http://www.w3.org/2000/01/rdf-schema#label attention layer
# http://example.org/myv/concept/attention_score http://www.w3.org/2000/01/rdf-schema#label attention score
# http://example.org/myv/concept/attitudes http://www.w3.org/2000/01/rdf-schema#label attitudes
# http://example.org/myv/concept/auc http://www.w3.org/2000/01/rdf-schema#label auc
# http://example.org/myv/concept/audience_analysis http://www.w3.org/2000/01/rdf-schema#label audience analysis
# http://example.org/myv/concept/audience_feedback http://www.w3.org/2000/01/rdf-schema#label audience feedback
# http://example.org/myv/concept/audiences http://www.w3.org/2000/01/rdf-schema#label audiences
# http://example.org/myv/concept/audio http://www.w3.org/2000/01/rdf-schema#label audio
# http://example.org/myv/concept/audio_features http://www.w3.org/2000/01/rdf-schema#label audio features
# http://example.org/myv/concept/audio_to_text http://www.w3.org/2000/01/rdf-schema#label audio to text
# http://example.org/myv/concept/augmented_intelligence http://www.w3.org/2000/01/rdf-schema#label augmented intelligence
# http://example.org/myv/concept/augmented_reality http://www.w3.org/2000/01/rdf-schema#label augmented reality
# http://example.org/myv/concept/author_profiling http://www.w3.org/2000/01/rdf-schema#label author profiling
# http://example.org/myv/concept/auto_machine_learning http://www.w3.org/2000/01/rdf-schema#label auto machine learning
# http://example.org/myv/concept/automated_analytics_framework http://www.w3.org/2000/01/rdf-schema#label automated analytics framework
# http://example.org/myv/concept/automated_approaches http://www.w3.org/2000/01/rdf-schema#label automated approaches
# http://example.org/myv/concept/automated_content_analysis http://www.w3.org/2000/01/rdf-schema#label automated content analysis
# http://example.org/myv/concept/automated_review_analysis http://www.w3.org/2000/01/rdf-schema#label automated review analysis
# http://example.org/myv/concept/automatic_depression_detection http://www.w3.org/2000/01/rdf-schema#label automatic depression detection
# http://example.org/myv/concept/automatic_hate_speech_identification_hate_speech_alt-right_youtube_interdisciplinary_research http://www.w3.org/2000/01/rdf-schema#label automatic hate speech identification; hate speech; alt-right; youtube; interdisciplinary research
# http://example.org/myv/concept/averaging http://www.w3.org/2000/01/rdf-schema#label averaging
# http://example.org/myv/concept/aviation_sector http://www.w3.org/2000/01/rdf-schema#label aviation sector
# http://example.org/myv/concept/azure http://www.w3.org/2000/01/rdf-schema#label azure
# http://example.org/myv/concept/azure_machine_learning http://www.w3.org/2000/01/rdf-schema#label azure machine learning
# http://example.org/myv/concept/azure_services http://www.w3.org/2000/01/rdf-schema#label azure services
# http://example.org/myv/concept/bag_of_words_bow http://www.w3.org/2000/01/rdf-schema#label bag of words (bow)
# http://example.org/myv/concept/balanced_scorecard http://www.w3.org/2000/01/rdf-schema#label balanced scorecard
# http://example.org/myv/concept/bangla http://www.w3.org/2000/01/rdf-schema#label bangla
# http://example.org/myv/concept/bangla_abusive_words http://www.w3.org/2000/01/rdf-schema#label bangla abusive words
# http://example.org/myv/concept/bangla_dataset http://www.w3.org/2000/01/rdf-schema#label bangla dataset
# http://example.org/myv/concept/bangla_language http://www.w3.org/2000/01/rdf-schema#label bangla language
# http://example.org/myv/concept/bangla_language_processing http://www.w3.org/2000/01/rdf-schema#label bangla language processing
# http://example.org/myv/concept/bangla_nlp http://www.w3.org/2000/01/rdf-schema#label bangla nlp
# http://example.org/myv/concept/bangla_social_media_tweets http://www.w3.org/2000/01/rdf-schema#label bangla social media tweets
# http://example.org/myv/concept/bangla_texts http://www.w3.org/2000/01/rdf-schema#label bangla texts
# http://example.org/myv/concept/bangladesh http://www.w3.org/2000/01/rdf-schema#label bangladesh
# http://example.org/myv/concept/bangladeshi_food_review http://www.w3.org/2000/01/rdf-schema#label bangladeshi food review
# http://example.org/myv/concept/banglish http://www.w3.org/2000/01/rdf-schema#label banglish
# http://example.org/myv/concept/banglish_text http://www.w3.org/2000/01/rdf-schema#label banglish text
# http://example.org/myv/concept/banking_services http://www.w3.org/2000/01/rdf-schema#label banking services
# http://example.org/myv/concept/bart http://www.w3.org/2000/01/rdf-schema#label bart
# http://example.org/myv/concept/base http://www.w3.org/2000/01/rdf-schema#label base
# http://example.org/myv/concept/base_learners http://www.w3.org/2000/01/rdf-schema#label base learners
# http://example.org/myv/concept/basic_emotion_classification http://www.w3.org/2000/01/rdf-schema#label basic emotion classification
# http://example.org/myv/concept/basic_emotions http://www.w3.org/2000/01/rdf-schema#label basic emotions
# http://example.org/myv/concept/bat_algorithm http://www.w3.org/2000/01/rdf-schema#label bat algorithm
# http://example.org/myv/concept/bayesian_algorithm http://www.w3.org/2000/01/rdf-schema#label bayesian algorithm
# http://example.org/myv/concept/bayesian_approach http://www.w3.org/2000/01/rdf-schema#label bayesian approach
# http://example.org/myv/concept/bayesian_inference http://www.w3.org/2000/01/rdf-schema#label bayesian inference
# http://example.org/myv/concept/bayesian_models http://www.w3.org/2000/01/rdf-schema#label bayesian models
# http://example.org/myv/concept/bayesian_networks http://www.w3.org/2000/01/rdf-schema#label bayesian networks
# http://example.org/myv/concept/bayesian_networks_maximum_entropy http://www.w3.org/2000/01/rdf-schema#label bayesian networks maximum entropy
# http://example.org/myv/concept/bayesian_optimization http://www.w3.org/2000/01/rdf-schema#label bayesian optimization
# http://example.org/myv/concept/beauty_products http://www.w3.org/2000/01/rdf-schema#label beauty products
# http://example.org/myv/concept/behavior_change http://www.w3.org/2000/01/rdf-schema#label behavior change
# http://example.org/myv/concept/behavioral_analysis http://www.w3.org/2000/01/rdf-schema#label behavioral analysis
# http://example.org/myv/concept/behavioral_outcome http://www.w3.org/2000/01/rdf-schema#label behavioral outcome
# http://example.org/myv/concept/behaviour_analysis http://www.w3.org/2000/01/rdf-schema#label behaviour analysis
# http://example.org/myv/concept/behavioural_analysis http://www.w3.org/2000/01/rdf-schema#label behavioural analysis
# http://example.org/myv/concept/behavioural_finance http://www.w3.org/2000/01/rdf-schema#label behavioural finance
# http://example.org/myv/concept/behavioural_intentions http://www.w3.org/2000/01/rdf-schema#label behavioural intentions
# http://example.org/myv/concept/benchmark_datasets http://www.w3.org/2000/01/rdf-schema#label benchmark datasets
# http://example.org/myv/concept/bengali_comment http://www.w3.org/2000/01/rdf-schema#label bengali comment
# http://example.org/myv/concept/bengali_comment_collection_from_youtube http://www.w3.org/2000/01/rdf-schema#label bengali comment collection from youtube
# http://example.org/myv/concept/bengali_dataset http://www.w3.org/2000/01/rdf-schema#label bengali dataset
# http://example.org/myv/concept/bengali_language http://www.w3.org/2000/01/rdf-schema#label bengali language
# http://example.org/myv/concept/bengali_sentiment_dataset http://www.w3.org/2000/01/rdf-schema#label bengali sentiment dataset
# http://example.org/myv/concept/bengali_text http://www.w3.org/2000/01/rdf-schema#label bengali text
# http://example.org/myv/concept/bengali_text_analysis http://www.w3.org/2000/01/rdf-schema#label bengali text analysis
# http://example.org/myv/concept/bernoulli_naive_bayes http://www.w3.org/2000/01/rdf-schema#label bernoulli naive bayes
# http://example.org/myv/concept/bernoulli_nave_bayes_bnb http://www.w3.org/2000/01/rdf-schema#label bernoulli naïve bayes (bnb)
# http://example.org/myv/concept/bernoullinb http://www.w3.org/2000/01/rdf-schema#label bernoullinb
# http://example.org/myv/concept/bert-bilstm http://www.w3.org/2000/01/rdf-schema#label bert-bilstm
# http://example.org/myv/concept/bert__nbsvm http://www.w3.org/2000/01/rdf-schema#label bert + nbsvm
# http://example.org/myv/concept/bert_and_bart http://www.w3.org/2000/01/rdf-schema#label bert and bart
# http://example.org/myv/concept/bert_classifier http://www.w3.org/2000/01/rdf-schema#label bert classifier
# http://example.org/myv/concept/bertimbau http://www.w3.org/2000/01/rdf-schema#label bertimbau
# http://example.org/myv/concept/bertopic http://www.w3.org/2000/01/rdf-schema#label bertopic
# http://example.org/myv/concept/berttopic http://www.w3.org/2000/01/rdf-schema#label berttopic
# http://example.org/myv/concept/bertweet http://www.w3.org/2000/01/rdf-schema#label bertweet
# http://example.org/myv/concept/beto http://www.w3.org/2000/01/rdf-schema#label beto
# http://example.org/myv/concept/bi-directional_lstm http://www.w3.org/2000/01/rdf-schema#label bi-directional lstm
# http://example.org/myv/concept/bi-functional_algorithms http://www.w3.org/2000/01/rdf-schema#label bi-functional algorithms.
# http://example.org/myv/concept/bi-gru-lstm-cnn http://www.w3.org/2000/01/rdf-schema#label bi-gru-lstm-cnn
# http://example.org/myv/concept/bi-mode http://www.w3.org/2000/01/rdf-schema#label bi-mode
# http://example.org/myv/concept/bi-tagged_features http://www.w3.org/2000/01/rdf-schema#label bi-tagged features
# http://example.org/myv/concept/bi_lstm http://www.w3.org/2000/01/rdf-schema#label bi lstm
# http://example.org/myv/concept/bias http://www.w3.org/2000/01/rdf-schema#label bias
# http://example.org/myv/concept/bibliometric_analysis http://www.w3.org/2000/01/rdf-schema#label bibliometric analysis
# http://example.org/myv/concept/bibliometrics http://www.w3.org/2000/01/rdf-schema#label bibliometrics
# http://example.org/myv/concept/bidirection_encoder_representations_from_transformers http://www.w3.org/2000/01/rdf-schema#label bidirection encoder representations from transformers
# http://example.org/myv/concept/bidirectional_encoder_representation_from_transformers http://www.w3.org/2000/01/rdf-schema#label bidirectional encoder representation from transformers
# http://example.org/myv/concept/bidirectional_encoder_representation_from_transformers_bert http://www.w3.org/2000/01/rdf-schema#label bidirectional encoder representation from transformers (bert)
# http://example.org/myv/concept/bidirectional_encoder_representations_from_transformersbert http://www.w3.org/2000/01/rdf-schema#label bidirectional encoder representations from transformers(bert)
# http://example.org/myv/concept/bidirectional_encoders_for_representational_transformers http://www.w3.org/2000/01/rdf-schema#label bidirectional encoders for representational transformers
# http://example.org/myv/concept/bidirectional_gated_recurrent_unit http://www.w3.org/2000/01/rdf-schema#label bidirectional gated recurrent unit
# http://example.org/myv/concept/bidirectional_long-short_term_memory_bilstm http://www.w3.org/2000/01/rdf-schema#label bidirectional long-short term memory (bilstm)
# http://example.org/myv/concept/bidirectional_long_and_short-term_memory_bilstm http://www.w3.org/2000/01/rdf-schema#label bidirectional long and short-term memory (bilstm)
# http://example.org/myv/concept/bidirectional_long_short-term_memory_bi-_lstm http://www.w3.org/2000/01/rdf-schema#label bidirectional long short-term memory (bi- lstm)
# http://example.org/myv/concept/bidirectional_long_short_term_memory_bi-lstm http://www.w3.org/2000/01/rdf-schema#label bidirectional long short term memory (bi-lstm)
# http://example.org/myv/concept/big_data_analysis http://www.w3.org/2000/01/rdf-schema#label big data analysis
# http://example.org/myv/concept/big_data_analytic http://www.w3.org/2000/01/rdf-schema#label big data analytic
# http://example.org/myv/concept/big_data_management_in_iot http://www.w3.org/2000/01/rdf-schema#label big data management in iot
# http://example.org/myv/concept/big_data_processing http://www.w3.org/2000/01/rdf-schema#label big data processing
# http://example.org/myv/concept/big_social_data http://www.w3.org/2000/01/rdf-schema#label big social data
# http://example.org/myv/concept/bigru http://www.w3.org/2000/01/rdf-schema#label bigru
# http://example.org/myv/concept/bigru-cnn_hybrid http://www.w3.org/2000/01/rdf-schema#label bigru-cnn hybrid
# http://example.org/myv/concept/biking http://www.w3.org/2000/01/rdf-schema#label biking
# http://example.org/myv/concept/bilingual_sentiment_analysis http://www.w3.org/2000/01/rdf-schema#label bilingual sentiment analysis
# http://example.org/myv/concept/bilstm_attention_model http://www.w3.org/2000/01/rdf-schema#label bilstm attention model
# http://example.org/myv/concept/binary-first_tree http://www.w3.org/2000/01/rdf-schema#label binary-first tree
# http://example.org/myv/concept/binary_class_classification http://www.w3.org/2000/01/rdf-schema#label binary class classification
# http://example.org/myv/concept/binjhal_language http://www.w3.org/2000/01/rdf-schema#label binjhal language
# http://example.org/myv/concept/bio-contact http://www.w3.org/2000/01/rdf-schema#label bio-contact
# http://example.org/myv/concept/bio-inspired_adaptation http://www.w3.org/2000/01/rdf-schema#label bio-inspired adaptation
# http://example.org/myv/concept/biodisaster_x http://www.w3.org/2000/01/rdf-schema#label biodisaster x
# http://example.org/myv/concept/biodisasters http://www.w3.org/2000/01/rdf-schema#label biodisasters
# http://example.org/myv/concept/biography_generation http://www.w3.org/2000/01/rdf-schema#label biography generation
# http://example.org/myv/concept/bioinspired_algorithms http://www.w3.org/2000/01/rdf-schema#label bioinspired algorithms
# http://example.org/myv/concept/biomedical_communication http://www.w3.org/2000/01/rdf-schema#label biomedical communication
# http://example.org/myv/concept/biomedical_engineering http://www.w3.org/2000/01/rdf-schema#label biomedical engineering
# http://example.org/myv/concept/biomedical_informatics http://www.w3.org/2000/01/rdf-schema#label biomedical informatics
# http://example.org/myv/concept/biomedical_sense_disambiguation http://www.w3.org/2000/01/rdf-schema#label biomedical sense disambiguation
# http://example.org/myv/concept/biosafety http://www.w3.org/2000/01/rdf-schema#label biosafety
# http://example.org/myv/concept/biosurveillance http://www.w3.org/2000/01/rdf-schema#label biosurveillance
# http://example.org/myv/concept/biotechnology http://www.w3.org/2000/01/rdf-schema#label biotechnology
# http://example.org/myv/concept/bioterrorism http://www.w3.org/2000/01/rdf-schema#label bioterrorism
# http://example.org/myv/concept/bipolar_disorder http://www.w3.org/2000/01/rdf-schema#label bipolar disorder
# http://example.org/myv/concept/birth_control http://www.w3.org/2000/01/rdf-schema#label birth control
# http://example.org/myv/concept/birth_outcomes http://www.w3.org/2000/01/rdf-schema#label birth outcomes
# http://example.org/myv/concept/bitcoins http://www.w3.org/2000/01/rdf-schema#label bitcoins
# http://example.org/myv/concept/biterm_topic_model http://www.w3.org/2000/01/rdf-schema#label biterm topic model
# http://example.org/myv/concept/black_lives_matter http://www.w3.org/2000/01/rdf-schema#label black lives matter
# ...
# http://example.org/myv/concept/user-generated_content http://www.w3.org/2000/01/rdf-schema#label user-generated content
# http://example.org/myv/concept/cryptocurrency http://www.w3.org/2000/01/rdf-schema#label cryptocurrency
# http://example.org/myv/concept/data_visualization http://www.w3.org/2000/01/rdf-schema#label data visualization
# http://example.org/myv/concept/dataset http://www.w3.org/2000/01/rdf-schema#label dataset
# http://example.org/myv/concept/detection http://www.w3.org/2000/01/rdf-schema#label detection
# http://example.org/myv/concept/ensemble http://www.w3.org/2000/01/rdf-schema#label ensemble
# http://example.org/myv/concept/fasttext http://www.w3.org/2000/01/rdf-schema#label fasttext
# http://example.org/myv/concept/feature_engineering http://www.w3.org/2000/01/rdf-schema#label feature engineering
# http://example.org/myv/concept/gru http://www.w3.org/2000/01/rdf-schema#label gru
# http://example.org/myv/concept/health_informatics http://www.w3.org/2000/01/rdf-schema#label health informatics
# http://example.org/myv/concept/instagram http://www.w3.org/2000/01/rdf-schema#label instagram
# http://example.org/myv/concept/optimization http://www.w3.org/2000/01/rdf-schema#label optimization
# http://example.org/myv/concept/politics http://www.w3.org/2000/01/rdf-schema#label politics
# http://example.org/myv/concept/smote http://www.w3.org/2000/01/rdf-schema#label smote
# http://example.org/myv/concept/text_analytics http://www.w3.org/2000/01/rdf-schema#label text analytics
# http://example.org/myv/concept/tweet http://www.w3.org/2000/01/rdf-schema#label tweet
# http://example.org/myv/concept/visualization http://www.w3.org/2000/01/rdf-schema#label visualization
# http://example.org/myv/concept/arabic_language http://www.w3.org/2000/01/rdf-schema#label arabic language
# http://example.org/myv/concept/aspect-based_sentiment_analysis http://www.w3.org/2000/01/rdf-schema#label aspect-based sentiment analysis
# http://example.org/myv/concept/bert_model http://www.w3.org/2000/01/rdf-schema#label bert model
# http://example.org/myv/concept/data_analysis http://www.w3.org/2000/01/rdf-schema#label data analysis
# http://example.org/myv/concept/data_analytics http://www.w3.org/2000/01/rdf-schema#label data analytics
# http://example.org/myv/concept/emotion_classification http://www.w3.org/2000/01/rdf-schema#label emotion classification
# http://example.org/myv/concept/fake_news_detection http://www.w3.org/2000/01/rdf-schema#label fake news detection
# http://example.org/myv/concept/healthcare http://www.w3.org/2000/01/rdf-schema#label healthcare
# http://example.org/myv/concept/k-nearest_neighbor http://www.w3.org/2000/01/rdf-schema#label k-nearest neighbor
# http://example.org/myv/concept/lda http://www.w3.org/2000/01/rdf-schema#label lda
# http://example.org/myv/concept/misinformation http://www.w3.org/2000/01/rdf-schema#label misinformation
# http://example.org/myv/concept/preprocessing http://www.w3.org/2000/01/rdf-schema#label preprocessing
# http://example.org/myv/concept/reddit http://www.w3.org/2000/01/rdf-schema#label reddit
# http://example.org/myv/concept/stock_prediction http://www.w3.org/2000/01/rdf-schema#label stock prediction
# http://example.org/myv/concept/word_embeddings http://www.w3.org/2000/01/rdf-schema#label word embeddings
# http://example.org/myv/concept/youtube http://www.w3.org/2000/01/rdf-schema#label youtube
# http://example.org/myv/concept/covid-19_vaccination http://www.w3.org/2000/01/rdf-schema#label covid-19 vaccination
# http://example.org/myv/concept/emotion http://www.w3.org/2000/01/rdf-schema#label emotion
# http://example.org/myv/concept/ensemble_model http://www.w3.org/2000/01/rdf-schema#label ensemble model
# http://example.org/myv/concept/prediction http://www.w3.org/2000/01/rdf-schema#label prediction
# http://example.org/myv/concept/python http://www.w3.org/2000/01/rdf-schema#label python
# http://example.org/myv/concept/python http://www.w3.org/2000/01/rdf-schema#label python.
# http://example.org/myv/concept/roberta http://www.w3.org/2000/01/rdf-schema#label roberta
# http://example.org/myv/concept/sarcasm http://www.w3.org/2000/01/rdf-schema#label sarcasm
# http://example.org/myv/concept/twitter_sentiment_analysis http://www.w3.org/2000/01/rdf-schema#label twitter sentiment analysis
# http://example.org/myv/concept/vaccines http://www.w3.org/2000/01/rdf-schema#label vaccines
# http://example.org/myv/concept/bilstm http://www.w3.org/2000/01/rdf-schema#label bilstm
# http://example.org/myv/concept/clustering http://www.w3.org/2000/01/rdf-schema#label clustering
# http://example.org/myv/concept/content_analysis http://www.w3.org/2000/01/rdf-schema#label content analysis
# http://example.org/myv/concept/covid-19_pandemic http://www.w3.org/2000/01/rdf-schema#label covid-19 pandemic
# http://example.org/myv/concept/covid-19_vaccine http://www.w3.org/2000/01/rdf-schema#label covid-19 vaccine
# http://example.org/myv/concept/data_science http://www.w3.org/2000/01/rdf-schema#label data science
# http://example.org/myv/concept/ml http://www.w3.org/2000/01/rdf-schema#label ml
# http://example.org/myv/concept/tourism http://www.w3.org/2000/01/rdf-schema#label tourism
# http://example.org/myv/concept/emotion_recognition http://www.w3.org/2000/01/rdf-schema#label emotion recognition
# http://example.org/myv/concept/infodemiology http://www.w3.org/2000/01/rdf-schema#label infodemiology
# http://example.org/myv/concept/latent_dirichlet_allocation http://www.w3.org/2000/01/rdf-schema#label latent dirichlet allocation
# http://example.org/myv/concept/machine_learning_algorithm http://www.w3.org/2000/01/rdf-schema#label machine learning algorithm
# http://example.org/myv/concept/nltk http://www.w3.org/2000/01/rdf-schema#label nltk
# http://example.org/myv/concept/recurrent_neural_network http://www.w3.org/2000/01/rdf-schema#label recurrent neural network
# http://example.org/myv/concept/sentiments http://www.w3.org/2000/01/rdf-schema#label sentiments
# http://example.org/myv/concept/deep_learning_dl http://www.w3.org/2000/01/rdf-schema#label deep learning (dl)
# http://example.org/myv/concept/emotions http://www.w3.org/2000/01/rdf-schema#label emotions
# http://example.org/myv/concept/xgboost http://www.w3.org/2000/01/rdf-schema#label xgboost
# http://example.org/myv/concept/public_health http://www.w3.org/2000/01/rdf-schema#label public health
# http://example.org/myv/concept/public_opinion http://www.w3.org/2000/01/rdf-schema#label public opinion
# http://example.org/myv/concept/social_media_data http://www.w3.org/2000/01/rdf-schema#label social media data
# http://example.org/myv/concept/stock_market http://www.w3.org/2000/01/rdf-schema#label stock market
# http://example.org/myv/concept/support_vector_machines http://www.w3.org/2000/01/rdf-schema#label support vector machines
# http://example.org/myv/concept/topic_modelling http://www.w3.org/2000/01/rdf-schema#label topic modelling
# http://example.org/myv/concept/vaccine http://www.w3.org/2000/01/rdf-schema#label vaccine
# http://example.org/myv/concept/vaccine_hesitancy http://www.w3.org/2000/01/rdf-schema#label vaccine hesitancy
# http://example.org/myv/concept/accuracy http://www.w3.org/2000/01/rdf-schema#label accuracy
# http://example.org/myv/concept/arabic_sentiment_analysis http://www.w3.org/2000/01/rdf-schema#label arabic sentiment analysis
# http://example.org/myv/concept/bi-lstm http://www.w3.org/2000/01/rdf-schema#label bi-lstm
# http://example.org/myv/concept/depression_detection http://www.w3.org/2000/01/rdf-schema#label depression detection
# http://example.org/myv/concept/knn http://www.w3.org/2000/01/rdf-schema#label knn
# http://example.org/myv/concept/supervised_learning http://www.w3.org/2000/01/rdf-schema#label supervised learning
# http://example.org/myv/concept/supervised_machine_learning http://www.w3.org/2000/01/rdf-schema#label supervised machine learning
# http://example.org/myv/concept/textblob http://www.w3.org/2000/01/rdf-schema#label textblob
# http://example.org/myv/concept/transformers http://www.w3.org/2000/01/rdf-schema#label transformers
# http://example.org/myv/concept/word2vec http://www.w3.org/2000/01/rdf-schema#label word2vec
# http://example.org/myv/concept/polarity http://www.w3.org/2000/01/rdf-schema#label polarity
# http://example.org/myv/concept/text_analysis http://www.w3.org/2000/01/rdf-schema#label text analysis
# http://example.org/myv/concept/transfer_learning http://www.w3.org/2000/01/rdf-schema#label transfer learning
# http://example.org/myv/concept/coronavirus http://www.w3.org/2000/01/rdf-schema#label coronavirus
# http://example.org/myv/concept/facebook http://www.w3.org/2000/01/rdf-schema#label facebook
# http://example.org/myv/concept/long_short-term_memory http://www.w3.org/2000/01/rdf-schema#label long short-term memory
# http://example.org/myv/concept/support_vector_machine_svm http://www.w3.org/2000/01/rdf-schema#label support vector machine (svm)
# http://example.org/myv/concept/cyberbullying http://www.w3.org/2000/01/rdf-schema#label cyberbullying
# http://example.org/myv/concept/emotion_analysis http://www.w3.org/2000/01/rdf-schema#label emotion analysis
# http://example.org/myv/concept/social_network http://www.w3.org/2000/01/rdf-schema#label social network
# http://example.org/myv/concept/vaccination http://www.w3.org/2000/01/rdf-schema#label vaccination
# http://example.org/myv/concept/lexicon http://www.w3.org/2000/01/rdf-schema#label lexicon
# http://example.org/myv/concept/pandemic http://www.w3.org/2000/01/rdf-schema#label pandemic
# http://example.org/myv/concept/vader http://www.w3.org/2000/01/rdf-schema#label vader
# http://example.org/myv/concept/feature_selection http://www.w3.org/2000/01/rdf-schema#label feature selection
# http://example.org/myv/concept/social_network_analysis http://www.w3.org/2000/01/rdf-schema#label social network analysis
# http://example.org/myv/concept/hate_speech http://www.w3.org/2000/01/rdf-schema#label hate speech
# http://example.org/myv/concept/neural_networks http://www.w3.org/2000/01/rdf-schema#label neural networks
# http://example.org/myv/concept/sentiment_analysis_sa http://www.w3.org/2000/01/rdf-schema#label sentiment analysis (s.a)
# http://example.org/myv/concept/sentiment_analysis_sa http://www.w3.org/2000/01/rdf-schema#label sentiment analysis (sa)
# http://example.org/myv/concept/convolutional_neural_network http://www.w3.org/2000/01/rdf-schema#label convolutional neural network
# http://example.org/myv/concept/machine_learning_algorithms http://www.w3.org/2000/01/rdf-schema#label machine learning algorithms
# http://example.org/myv/concept/neural_network http://www.w3.org/2000/01/rdf-schema#label neural network
# http://example.org/myv/concept/social_networks http://www.w3.org/2000/01/rdf-schema#label social networks
# http://example.org/myv/concept/emotion_detection http://www.w3.org/2000/01/rdf-schema#label emotion detection
# http://example.org/myv/concept/ensemble_learning http://www.w3.org/2000/01/rdf-schema#label ensemble learning
# http://example.org/myv/concept/rnn http://www.w3.org/2000/01/rdf-schema#label rnn
# http://example.org/myv/concept/mental_health http://www.w3.org/2000/01/rdf-schema#label mental health
# http://example.org/myv/concept/twitter_data http://www.w3.org/2000/01/rdf-schema#label twitter data
# http://example.org/myv/concept/sarcasm_detection http://www.w3.org/2000/01/rdf-schema#label sarcasm detection
# http://example.org/myv/concept/tf-idf http://www.w3.org/2000/01/rdf-schema#label tf-idf
# http://example.org/myv/concept/social_media_analysis http://www.w3.org/2000/01/rdf-schema#label social media analysis
# http://example.org/myv/concept/fake_news http://www.w3.org/2000/01/rdf-schema#label fake news
# http://example.org/myv/concept/social_media_analytics http://www.w3.org/2000/01/rdf-schema#label social media analytics
# http://example.org/myv/concept/sentiment_classification http://www.w3.org/2000/01/rdf-schema#label sentiment classification
# http://example.org/myv/concept/machine_learning_ml http://www.w3.org/2000/01/rdf-schema#label machine learning (ml)
# http://example.org/myv/concept/sentimental_analysis http://www.w3.org/2000/01/rdf-schema#label sentimental analysis
# http://example.org/myv/concept/decision_tree http://www.w3.org/2000/01/rdf-schema#label decision tree
# http://example.org/myv/concept/depression http://www.w3.org/2000/01/rdf-schema#label depression
# http://example.org/myv/concept/sentiment http://www.w3.org/2000/01/rdf-schema#label sentiment
# http://example.org/myv/concept/tweets http://www.w3.org/2000/01/rdf-schema#label tweets
# http://example.org/myv/concept/tweets http://www.w3.org/2000/01/rdf-schema#label tweets.
# http://example.org/myv/concept/word_embedding http://www.w3.org/2000/01/rdf-schema#label word embedding
# http://example.org/myv/concept/data_mining http://www.w3.org/2000/01/rdf-schema#label data mining
# http://example.org/myv/concept/feature_extraction http://www.w3.org/2000/01/rdf-schema#label feature extraction
# http://example.org/myv/concept/naive_bayes http://www.w3.org/2000/01/rdf-schema#label naive bayes
# http://example.org/myv/concept/big_data http://www.w3.org/2000/01/rdf-schema#label big data
# http://example.org/myv/concept/topic_modeling http://www.w3.org/2000/01/rdf-schema#label topic modeling
# http://example.org/myv/concept/cnn http://www.w3.org/2000/01/rdf-schema#label cnn
# http://example.org/myv/concept/natural_language_processing_nlp http://www.w3.org/2000/01/rdf-schema#label natural language processing (nlp)
# http://example.org/myv/concept/natural_language_processing_nlp http://www.w3.org/2000/01/rdf-schema#label natural language processing nlp
# http://example.org/myv/concept/nave_bayes http://www.w3.org/2000/01/rdf-schema#label nave bayes
# http://example.org/myv/concept/nave_bayes http://www.w3.org/2000/01/rdf-schema#label naïve bayes
# http://example.org/myv/concept/nave_bayes http://www.w3.org/2000/01/rdf-schema#label naïve baye’s
# http://example.org/myv/concept/text_classification http://www.w3.org/2000/01/rdf-schema#label text classification
# http://example.org/myv/concept/svm http://www.w3.org/2000/01/rdf-schema#label svm
# http://example.org/myv/concept/artificial_intelligence http://www.w3.org/2000/01/rdf-schema#label artificial intelligence
# http://example.org/myv/concept/bert http://www.w3.org/2000/01/rdf-schema#label bert
# http://example.org/myv/concept/bert http://www.w3.org/2000/01/rdf-schema#label bert.
# http://example.org/myv/concept/logistic_regression http://www.w3.org/2000/01/rdf-schema#label logistic regression
# http://example.org/myv/concept/random_forest http://www.w3.org/2000/01/rdf-schema#label random forest
# http://example.org/myv/concept/classification http://www.w3.org/2000/01/rdf-schema#label classification
# http://example.org/myv/concept/lstm http://www.w3.org/2000/01/rdf-schema#label lstm
# http://example.org/myv/concept/lstm http://www.w3.org/2000/01/rdf-schema#label lstm.
# http://example.org/myv/concept/support_vector_machine http://www.w3.org/2000/01/rdf-schema#label support vector machine
# http://example.org/myv/concept/text_mining http://www.w3.org/2000/01/rdf-schema#label text mining
# http://example.org/myv/concept/nlp http://www.w3.org/2000/01/rdf-schema#label nlp
# http://example.org/myv/concept/opinion_mining http://www.w3.org/2000/01/rdf-schema#label opinion mining
# http://example.org/myv/concept/covid-19 http://www.w3.org/2000/01/rdf-schema#label covid-19
# http://example.org/myv/concept/twitter http://www.w3.org/2000/01/rdf-schema#label twitter
# http://example.org/myv/concept/deep_learning http://www.w3.org/2000/01/rdf-schema#label deep learning
# http://example.org/myv/concept/natural_language_processing http://www.w3.org/2000/01/rdf-schema#label natural language processing
# http://example.org/myv/concept/social_media http://www.w3.org/2000/01/rdf-schema#label social media
# http://example.org/myv/concept/machine_learning http://www.w3.org/2000/01/rdf-schema#label machine learning
# http://example.org/myv/concept/sentiment_analysis http://www.w3.org/2000/01/rdf-schema#label sentiment analysis
# http://example.org/myv/concept/sentiment_analysis http://www.w3.org/2000/01/rdf-schema#label sentiment analysis
